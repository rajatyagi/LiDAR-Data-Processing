# %%
# !pip install velodyne_decoder
# Out:
# Requirement already satisfied: velodyne_decoder in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: numpy in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from velodyne_decoder) (1.24.2)
# Requirement already satisfied: importlib-resources in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from velodyne_decoder) (5.12.0)
# Requirement already satisfied: dpkt in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from velodyne_decoder) (1.9.8)

# %%
# !conda install -c menpo opencv
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.3.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/rajatyagi/anaconda3/envs/myenv
#
#   added / updated specs:
#     - opencv
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |         openblas          45 KB
#     cairo-1.16.0               |       h3ce6f7e_4        1011 KB
#     eigen-3.3.7                |       haf03e11_1         832 KB
#     expat-2.4.9                |       he9d5cce_0         127 KB
#     ffmpeg-4.2.2               |       h97e5cf8_0        22.9 MB
#     fontconfig-2.14.1          |       hb0a0c50_2         249 KB
#     gettext-0.21.0             |       he85b6c0_1         3.0 MB
#     glib-2.69.1                |       hfff2838_2         3.0 MB
#     gmp-6.2.1                  |       he9d5cce_3         525 KB
#     gnutls-3.6.15              |       hed9c0bf_0         974 KB
#     graphite2-1.3.14           |       he9d5cce_1          82 KB
#     gst-plugins-base-1.14.1    |       hcec6c5f_1         1.7 MB
#     gstreamer-1.14.1           |       h6c40b1e_1         1.7 MB
#     harfbuzz-4.3.0             |       hffc734d_1         1.2 MB
#     hdf5-1.10.6                |       h10fe05b_1         3.5 MB
#     krb5-1.19.4                |       hdba6334_0         1.2 MB
#     lame-3.100                 |       h1de35cc_0         316 KB
#     libclang-14.0.6            |default_hd95374b_1         138 KB
#     libclang13-14.0.6          |default_habbcc1a_1         7.1 MB
#     libedit-3.1.20221030       |       h6c40b1e_0         155 KB
#     libidn2-2.3.2              |       h9ed2024_0          85 KB
#     libllvm14-14.0.6           |       h91fad77_2        24.1 MB
#     libopus-1.3.1              |       h1de35cc_0         480 KB
#     libpq-12.9                 |       h1c9f633_3         2.0 MB
#     libtasn1-4.19.0            |       h6c40b1e_0          67 KB
#     libunistring-0.9.10        |       h9ed2024_0         519 KB
#     libvpx-1.7.0               |       h378b8a2_0         1.3 MB
#     nettle-3.7.3               |       h230ac6f_1         380 KB
#     nspr-4.33                  |       he9d5cce_0         228 KB
#     nss-3.74                   |       h47edf6a_0         1.8 MB
#     opencv-4.6.0               |  py310h3ea8b11_3        26.0 MB
#     openh264-2.1.1             |       h8346a28_0         655 KB
#     openjpeg-2.4.0             |       h66ea3da_0         301 KB
#     pcre-8.45                  |       h23ab428_0         181 KB
#     pixman-0.40.0              |       h9ed2024_1         341 KB
#     qt-main-5.15.2             |       h51e0635_8        44.6 MB
#     qt-webengine-5.15.9        |       h90a370e_4        48.2 MB
#     qtwebkit-5.212             |       hbfab81c_5        10.6 MB
#     x264-1!157.20191217        |       h1de35cc_0         910 KB
#     ------------------------------------------------------------
#                                            Total:       212.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/osx-64::blas-1.0-openblas
#   cairo              pkgs/main/osx-64::cairo-1.16.0-h3ce6f7e_4
#   eigen              pkgs/main/osx-64::eigen-3.3.7-haf03e11_1
#   expat              pkgs/main/osx-64::expat-2.4.9-he9d5cce_0
#   ffmpeg             pkgs/main/osx-64::ffmpeg-4.2.2-h97e5cf8_0
#   fontconfig         pkgs/main/osx-64::fontconfig-2.14.1-hb0a0c50_2
#   gettext            pkgs/main/osx-64::gettext-0.21.0-he85b6c0_1
#   glib               pkgs/main/osx-64::glib-2.69.1-hfff2838_2
#   gmp                pkgs/main/osx-64::gmp-6.2.1-he9d5cce_3
#   gnutls             pkgs/main/osx-64::gnutls-3.6.15-hed9c0bf_0
#   graphite2          pkgs/main/osx-64::graphite2-1.3.14-he9d5cce_1
#   gst-plugins-base   pkgs/main/osx-64::gst-plugins-base-1.14.1-hcec6c5f_1
#   gstreamer          pkgs/main/osx-64::gstreamer-1.14.1-h6c40b1e_1
#   harfbuzz           pkgs/main/osx-64::harfbuzz-4.3.0-hffc734d_1
#   hdf5               pkgs/main/osx-64::hdf5-1.10.6-h10fe05b_1
#   krb5               pkgs/main/osx-64::krb5-1.19.4-hdba6334_0
#   lame               pkgs/main/osx-64::lame-3.100-h1de35cc_0
#   libclang           pkgs/main/osx-64::libclang-14.0.6-default_hd95374b_1
#   libclang13         pkgs/main/osx-64::libclang13-14.0.6-default_habbcc1a_1
#   libedit            pkgs/main/osx-64::libedit-3.1.20221030-h6c40b1e_0
#   libidn2            pkgs/main/osx-64::libidn2-2.3.2-h9ed2024_0
#   libllvm14          pkgs/main/osx-64::libllvm14-14.0.6-h91fad77_2
#   libopus            pkgs/main/osx-64::libopus-1.3.1-h1de35cc_0
#   libpq              pkgs/main/osx-64::libpq-12.9-h1c9f633_3
#   libtasn1           pkgs/main/osx-64::libtasn1-4.19.0-h6c40b1e_0
#   libunistring       pkgs/main/osx-64::libunistring-0.9.10-h9ed2024_0
#   libvpx             pkgs/main/osx-64::libvpx-1.7.0-h378b8a2_0
#   nettle             pkgs/main/osx-64::nettle-3.7.3-h230ac6f_1
#   nspr               pkgs/main/osx-64::nspr-4.33-he9d5cce_0
#   nss                pkgs/main/osx-64::nss-3.74-h47edf6a_0
#   opencv             pkgs/main/osx-64::opencv-4.6.0-py310h3ea8b11_3
#   openh264           pkgs/main/osx-64::openh264-2.1.1-h8346a28_0
#   openjpeg           pkgs/main/osx-64::openjpeg-2.4.0-h66ea3da_0
#   pcre               pkgs/main/osx-64::pcre-8.45-h23ab428_0
#   pixman             pkgs/main/osx-64::pixman-0.40.0-h9ed2024_1
#   qt-main            pkgs/main/osx-64::qt-main-5.15.2-h51e0635_8
#   qt-webengine       pkgs/main/osx-64::qt-webengine-5.15.9-h90a370e_4
#   qtwebkit           pkgs/main/osx-64::qtwebkit-5.212-hbfab81c_5
#   x264               pkgs/main/osx-64::x264-1!157.20191217-h1de35cc_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2022.12.~ --> pkgs/main::ca-certificates-2023.01.10-hecd8cb5_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge/noarch::certifi-2022.12.7~ --> pkgs/main/osx-64::certifi-2022.12.7-py310hecd8cb5_0
#   openssl            conda-forge::openssl-1.1.1t-hfd90126_0 --> pkgs/main::openssl-1.1.1t-hca72f7f_0
#
#
# Proceed ([y]/n)? ^C
#
# CondaSystemExit:
# Operation aborted.  Exiting.

# %%
# !pip install open3d
# Out:
# Collecting open3d
#   Downloading open3d-0.16.1-cp310-cp310-macosx_10_15_x86_64.whl (74.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 MB 2.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pillow>=8.2.0 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from open3d) (9.4.0)
# Requirement already satisfied: tqdm in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from open3d) (4.65.0)
# Requirement already satisfied: numpy>1.15 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from open3d) (1.24.2)
# Collecting configargparse
#   Downloading ConfigArgParse-1.5.3-py3-none-any.whl (20 kB)
# Collecting dash>=2.6.0
#   Downloading dash-2.9.3-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 2.0 MB/s eta 0:00:0000:0100:01
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: matplotlib>=3 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from open3d) (3.7.1)
# Collecting pandas>=1.0
#   Downloading pandas-2.0.1-cp310-cp310-macosx_10_9_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 1.9 MB/s eta 0:00:0000:0100:01
# Collecting pyyaml>=5.4.1
#   Downloading PyYAML-6.0-cp310-cp310-macosx_10_9_x86_64.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.6/197.6 kB 2.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: scikit-learn>=0.21 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from open3d) (1.0.2)
# Collecting pyquaternion
#   Downloading pyquaternion-0.9.9-py3-none-any.whl (14 kB)
# Collecting nbformat==5.5.0
#   Downloading nbformat-5.5.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.3/75.3 kB 775.4 kB/s eta 0:00:00 0:00:01
# Requirement already satisfied: traitlets>=5.1 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from nbformat==5.5.0->open3d) (5.7.1)
# Requirement already satisfied: fastjsonschema in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from nbformat==5.5.0->open3d) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from nbformat==5.5.0->open3d) (4.17.3)
# Requirement already satisfied: jupyter_core in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from nbformat==5.5.0->open3d) (5.3.0)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting plotly>=5.0.0
#   Downloading plotly-5.14.1-py2.py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 2.1 MB/s eta 0:00:0000:0100:01
# Collecting Flask>=1.0.4
#   Downloading Flask-2.3.1-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.0/97.0 kB 2.3 MB/s eta 0:00:00
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3->open3d) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3->open3d) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3->open3d) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3->open3d) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3->open3d) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3->open3d) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3->open3d) (23.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from pandas>=1.0->open3d) (2022.7)
# Collecting tzdata>=2022.1
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Requirement already satisfied: scipy>=1.1.0 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from scikit-learn>=0.21->open3d) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from scikit-learn>=0.21->open3d) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from scikit-learn>=0.21->open3d) (1.1.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from Flask>=1.0.4->dash>=2.6.0->open3d) (3.1.2)
# Collecting itsdangerous>=2.1.2
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting click>=8.1.3
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 3.8 MB/s eta 0:00:00
# Collecting Werkzeug>=2.3.0
#   Downloading Werkzeug-2.3.1-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.0/242.0 kB 2.3 MB/s eta 0:00:00a 0:00:01
# Collecting blinker>=1.6.2
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat==5.5.0->open3d) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat==5.5.0->open3d) (22.1.0)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.2.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: six>=1.5 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3->open3d) (1.16.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from jupyter_core->nbformat==5.5.0->open3d) (2.5.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from Jinja2>=3.1.2->Flask>=1.0.4->dash>=2.6.0->open3d) (2.1.1)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, addict, Werkzeug, tzdata, tenacity, pyyaml, pyquaternion, itsdangerous, configargparse, click, blinker, plotly, pandas, nbformat, Flask, dash, open3d
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.7.0
#     Uninstalling nbformat-5.7.0:
#       Successfully uninstalled nbformat-5.7.0
# Successfully installed Flask-2.3.1 Werkzeug-2.3.1 addict-2.4.0 blinker-1.6.2 click-8.1.3 configargparse-1.5.3 dash-2.9.3 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 itsdangerous-2.1.2 nbformat-5.5.0 open3d-0.16.1 pandas-2.0.1 plotly-5.14.1 pyquaternion-0.9.9 pyyaml-6.0 tenacity-8.2.2 tzdata-2023.3

# %%
import velodyne_decoder as vd
from datetime import datetime
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import math
import scipy.io
import numpy as np
import cv2
import matplotlib.patches as patches
from PIL import Image
from sklearn.cluster import DBSCAN
import time
import open3d as o3d

# %%
# Functions

# Rotating the point clouds to be consistent with the video

def rotation_matrix(theta1, theta2, theta3, order='xyz'):
    c1 = np.cos(theta1 * np.pi / 180)
    s1 = np.sin(theta1 * np.pi / 180)
    c2 = np.cos(theta2 * np.pi / 180)
    s2 = np.sin(theta2 * np.pi / 180)
    c3 = np.cos(theta3 * np.pi / 180)
    s3 = np.sin(theta3 * np.pi / 180)
    matrix = np.array([[c2 * c3, -c2 * s3, s2],
                       [c1 * s3 + c3 * s1 * s2, c1 * c3 - s1 * s2 * s3, -c2 * s1],
                       [s1 * s3 - c1 * c3 * s2, c3 * s1 + c1 * s2 * s3, c1 * c2]])
    return matrix

# Converting to spherical co-ordinates 
def cart2sphA(xyz):
    ptsnew = np.zeros(xyz.shape)
    xy = xyz[:,0]**2 + xyz[:,1]**2
    ptsnew[:,0] = np.sqrt(xy + xyz[:,2]**2)
#     ptsnew[:,1] = np.arctan2(np.sqrt(xy), xyz[:,2]) # for elevation angle defined from Z-axis down
    ptsnew[:,1] = np.arctan2(xyz[:,2], np.sqrt(xy)) # for elevation angle defined from XY-plane up
    ptsnew[:,2] = np.arctan2(xyz[:,1], xyz[:,0])
    return ptsnew

# Cropping point cloud data.

def cropPtCloud(ptCloud):
    
    xLim = [-150, 150]
    yLim = [-150, 150]
    zLim = [-10, 10]
        
    insideX = np.logical_and(ptCloud[:,0] < xLim[1], ptCloud[:,0] > xLim[0])
    insideY = np.logical_and(ptCloud[:,1] < yLim[1], ptCloud[:,1] > yLim[0])
    insideZ = np.logical_and(ptCloud[:,2] < zLim[1], ptCloud[:,2] > zLim[0])
    
    validIndices = np.logical_and(np.logical_and(insideX, insideY), insideZ);
            
    return ptCloud[validIndices,:]

# %%
# Reading the Point Cloud Data

config = vd.Config(model='VLP-32C', rpm=600)
pcap_file = '../LiDAR_data.pcap'
stamps = []
cloud_arrays = []

# Reading the pcap file framewise
for stamp, pts in tqdm(vd.read_pcap(pcap_file, config)):
    points = np.zeros_like(pts)
    points[:,0] = -1*pts[:,1]
    points[:,1] = pts[:,0]
    points[:,2] = pts[:,2]
    cloud_arrays.append(points)
    stamps.append(stamp)
    
# # Converting 600 frames of Point Cloud data to spherical
# for i in tqdm(range(600)):
#     cloud_sph_arr.append(cart2sphA(cloud_arrays[i][:,0:3]))
# Out:
# 10627it [01:01, 173.70it/s]

# %%
# Load beams_elevation and range_thrld_matrix

range_thrld_matrix = scipy.io.loadmat('range_thrld_matrix.mat')
range_thrld_matrix = range_thrld_matrix['range_thrld_matrix']
beams_elevation = scipy.io.loadmat('beams_elevation_vlp32c.mat')
beams_elevation = beams_elevation['beams_elevation_vlp32c']

total_grid = 1800;
azimuth_unit = 360/total_grid;

filtered_point_cloud = []

for i in tqdm(range(600)):
    
    # Cropping the point cloud data and obtaining .
    cloud_array = cropPtCloud(cloud_arrays[i]);
    
    # Convert Cartesian to Spherical.
    cloud_sph_arr = cart2sphA(cloud_array[:,0:3])
    
    # Converting Azimuth from radians to degrees [0, 360]
    degree = cloud_sph_arr[:,2]
    degree = degree*180/3.14; # rad to deg
    degree[degree<0] = degree[degree<0] + 360
    
    # Assigning grids based on azimuth angle
    grids_idx = (np.floor(degree/azimuth_unit) + 1)%total_grid
    grids_idx[grids_idx == 0] = total_grid - 1  # deal with 1799 + 1 grid
    grids_idx[grids_idx == None] = 0 # LiDAR point NaN is set as 0
    grids_idx = grids_idx.astype(int)

    back_idxes = np.zeros(len(cloud_sph_arr))
    back_idxes[grids_idx == 0] = 1

    elevation_matrix = abs(np.zeros((len(beams_elevation),len(cloud_sph_arr))) + cloud_sph_arr[:,1] - beams_elevation)
    channel_num = np.argmin(elevation_matrix, axis = 0)

    mask = cloud_sph_arr[:,0] >=  range_thrld_matrix[channel_num, grids_idx]
    back_idxes[mask] = 1

    filtered_point_cloud.append(cloud_array[back_idxes == 0, 0:3])
    
#     # Point cloud filtering process
#     for pnt in (range(len(cloud_sph_arr))):
        
#         r = cloud_sph_arr[pnt,0]
#         elevation = cloud_sph_arr[pnt,1]
#         grid_idx = grids_idx[pnt]

#         if grid_idx == 0:
#             back_idxes[pnt] = 1
#             continue

#         channel_num = np.argmin(abs(beams_elevation - elevation))

#         if (r >= range_thrld_matrix[channel_num, grid_idx]):
#             back_idxes[pnt] = 1
            
#     filtered_point_cloud.append(cloud_array[back_idxes == 0, 0:3])
# Out:
# 100%|██████████| 600/600 [00:06<00:00, 86.97it/s]

# %%
# Rotating the point clouds to be consistent with the video
filtered_point_cloud_1 = []
for i in tqdm(range(len(filtered_point_cloud))):
    tmp = rotation_matrix(0, 0, -43).dot(filtered_point_cloud[i][:,0:3].T).T
    tmp = rotation_matrix(25, -5, 0).dot(tmp.T).T
    filtered_point_cloud_1.append(rotation_matrix(0, 0, 0).dot(tmp.T).T)
# Out:
# 100%|██████████| 600/600 [00:00<00:00, 2849.53it/s]

# %%
# !pip install fast_dbscan
# Out:
# Collecting fast_dbscan
#   Downloading fast_dbscan-0.1.1.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages (from fast_dbscan) (1.24.2)
# Building wheels for collected packages: fast_dbscan
#   Building wheel for fast_dbscan (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [31 lines of output]
#       /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages/setuptools/dist.py:770: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#         warnings.warn(
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-10.9-x86_64-cpython-310
#       creating build/lib.macosx-10.9-x86_64-cpython-310/fast_dbscan
#       copying fast_dbscan/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/fast_dbscan
#       copying fast_dbscan/fast_dbscan.py -> build/lib.macosx-10.9-x86_64-cpython-310/fast_dbscan
#       running build_ext
#       cythoning src/dbscan_module.pyx to src/dbscan_module.c
#       /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/j4/3gqr630j379_kfp9q68mc8b00000gn/T/pip-install-dsec25j7/fast-dbscan_3327ad9fcb884449b0e11fabba944556/src/dbscan_module.pyx
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       building 'dbscan' extension
#       creating build/temp.macosx-10.9-x86_64-cpython-310
#       creating build/temp.macosx-10.9-x86_64-cpython-310/src
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/rajatyagi/anaconda3/envs/myenv/include -fPIC -O2 -isystem /Users/rajatyagi/anaconda3/envs/myenv/include -Isrc/ -I/Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages/numpy/core/include -Isrc/ -I/Users/rajatyagi/anaconda3/envs/myenv/include/python3.10 -c src/dbscan.c -o build/temp.macosx-10.9-x86_64-cpython-310/src/dbscan.o
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/rajatyagi/anaconda3/envs/myenv/include -fPIC -O2 -isystem /Users/rajatyagi/anaconda3/envs/myenv/include -Isrc/ -I/Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages/numpy/core/include -Isrc/ -I/Users/rajatyagi/anaconda3/envs/myenv/include/python3.10 -c src/dbscan_module.c -o build/temp.macosx-10.9-x86_64-cpython-310/src/dbscan_module.o
#       In file included from src/dbscan_module.c:687:
#       In file included from /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages/numpy/core/include/numpy/arrayobject.h:5:
#       In file included from /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages/numpy/core/include/numpy/ndarrayobject.h:12:
#       In file included from /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages/numpy/core/include/numpy/ndarraytypes.h:1940:
#       /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: "Using deprecated NumPy API, disable it with "          "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#       #warning "Using deprecated NumPy API, disable it with " \
#        ^
#       src/dbscan_module.c:696:10: fatal error: 'dbscan.h' file not found
#       #include "dbscan.h"
#                ^~~~~~~~~~
#       1 warning and 1 error generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for fast_dbscan
#   Running setup.py clean for fast_dbscan
# Failed to build fast_dbscan
# Installing collected packages: fast_dbscan
#   Running setup.py install for fast_dbscan ... error
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for fast_dbscan did not run successfully.
#   │ exit code: 1
#   ╰─> [31 lines of output]
#       /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages/setuptools/dist.py:770: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#         warnings.warn(
#       running install
#       /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-10.9-x86_64-cpython-310
#       creating build/lib.macosx-10.9-x86_64-cpython-310/fast_dbscan
#       copying fast_dbscan/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/fast_dbscan
#       copying fast_dbscan/fast_dbscan.py -> build/lib.macosx-10.9-x86_64-cpython-310/fast_dbscan
#       running build_ext
#       skipping 'src/dbscan_module.c' Cython extension (up-to-date)
#       building 'dbscan' extension
#       creating build/temp.macosx-10.9-x86_64-cpython-310
#       creating build/temp.macosx-10.9-x86_64-cpython-310/src
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/rajatyagi/anaconda3/envs/myenv/include -fPIC -O2 -isystem /Users/rajatyagi/anaconda3/envs/myenv/include -Isrc/ -I/Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages/numpy/core/include -Isrc/ -I/Users/rajatyagi/anaconda3/envs/myenv/include/python3.10 -c src/dbscan.c -o build/temp.macosx-10.9-x86_64-cpython-310/src/dbscan.o
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/rajatyagi/anaconda3/envs/myenv/include -fPIC -O2 -isystem /Users/rajatyagi/anaconda3/envs/myenv/include -Isrc/ -I/Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages/numpy/core/include -Isrc/ -I/Users/rajatyagi/anaconda3/envs/myenv/include/python3.10 -c src/dbscan_module.c -o build/temp.macosx-10.9-x86_64-cpython-310/src/dbscan_module.o
#       In file included from src/dbscan_module.c:687:
#       In file included from /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages/numpy/core/include/numpy/arrayobject.h:5:
#       In file included from /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages/numpy/core/include/numpy/ndarrayobject.h:12:
#       In file included from /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages/numpy/core/include/numpy/ndarraytypes.h:1940:
#       /Users/rajatyagi/anaconda3/envs/myenv/lib/python3.10/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: "Using deprecated NumPy API, disable it with "          "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#       #warning "Using deprecated NumPy API, disable it with " \
#        ^
#       src/dbscan_module.c:696:10: fatal error: 'dbscan.h' file not found
#       #include "dbscan.h"
#                ^~~~~~~~~~
#       1 warning and 1 error generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> fast_dbscan
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
labels = np.array(
        pcd.cluster_dbscan(eps=0.02, min_points=10, print_progress=True))

# %%
from sklearn.cluster import DBSCAN
import time
X = filtered_point_cloud[399][:,0:2]
print(X.shape)
start_time  = time.time()
db = DBSCAN(eps=0.06, min_samples=17, algorithm='ball_tree', n_jobs=1).fit(X)
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print("Estimated number of clusters: %d" % n_clusters_)
print("Estimated number of noise points: %d" % n_noise_)
end_time = time.time()
print(end_time-start_time)
# Out:
# (7461, 2)
# Estimated number of clusters: 4
# Estimated number of noise points: 6301
# 0.019582271575927734

# %%
# Applying DBSCAN

# Sklearn DBSCAN Implementation

# clustered_point_cloud = []
# timings = []
# for i in tqdm(range(len(filtered_point_cloud))):
#     X = filtered_point_cloud_1[i][:,0:2]
#     start_time  = time.time()
#     db = DBSCAN(eps=1, min_samples=17, algorithm='ball_tree', n_jobs=1).fit(X)
#     end_time = time.time()
#     timings.append(end_time-start_time)
#     labels = db.labels_

#     # Number of clusters in labels, ignoring noise if present.
#     n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
#     n_noise_ = list(labels).count(-1)


#     # Storing a rectangle for each cluster for later plotting on image
#     rectangle_list = []
        
#     for j in range(n_clusters_):
#         class_member_mask = labels == j
#         xy = X[class_member_mask, :]
#         rectangle = [(int(125 + 20.5*np.min(xy[:, 0])), int(735 - 20*np.max(xy[:, 1]))), (int(125 + 20.5*np.max(xy[:, 0])), int(735 - 20*np.min(xy[:, 1])))]
#         rectangle_list.append(rectangle)
#     clustered_point_cloud.append(rectangle_list)
    
# # print(rectangle_list)

# Open 3D DBSCAN Implementation

clustered_point_cloud = []
timings = []
pcd = o3d.geometry.PointCloud()

# area = []

for i in tqdm(range(len(filtered_point_cloud))):
    
    X = filtered_point_cloud_1[i] 
    start_time = time.time()
    pcd.points = o3d.utility.Vector3dVector(X)
    labels_ = pcd.cluster_dbscan(eps=1, min_points=17)
    end_time = time.time()
    timings.append(end_time-start_time)
    labels = np.array(labels_)

    # Number of clusters in labels, ignoring noise if present.
    n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
    n_noise_ = list(labels).count(-1)


    # Storing a rectangle for each cluster for later plotting on image
    rectangle_list = []
        
    for j in range(n_clusters_):
        class_member_mask = labels == j
        xy = X[class_member_mask, :]
#         area.append(abs((int(735 - 20*np.min(xy[:, 1])) - int(735 - 20*np.max(xy[:, 1]))) * (int(125 + 20.5*np.min(xy[:, 0]))- int(125 + 20.5*np.max(xy[:, 0])))))
        rectangle = [(int(125 + 20.5*np.min(xy[:, 0])), int(735 - 20*np.max(xy[:, 1]))), (int(125 + 20.5*np.max(xy[:, 0])), int(735 - 20*np.min(xy[:, 1])))]
        rectangle_list.append(rectangle)
    clustered_point_cloud.append(rectangle_list)
    
print("Average Time Taken for Clustering", np.mean(timings))
# Out:
# 100%|██████████| 600/600 [00:29<00:00, 20.56it/s]
# Average Time Taken for Clustering 0.0351078736782074

# %%
n, bins, patches = plt.hist(x=np.asarray(area), bins='auto', color='#0504aa',
                            alpha=0.8, rwidth=0.85)
plt.show()
print(idx)
# Out:
# 399

# %%
# writing on the video
from motpy import Detection, MultiObjectTracker
cap = cv2.VideoCapture('../Videos/output1640b_transformed.mp4')
out = cv2.VideoWriter('../Videos/synchronization_filtered_demo.mp4', cv2.VideoWriter_fourcc(*'mp4v'), 15, (832, 832))

counter = 0
from motpy import Detection, MultiObjectTracker
tracker = MultiObjectTracker(dt=1./15.)

for i in range(43):
    ret, frame = cap.read()
    
time_stamp = stamps[0]
idx = 0
    
area = []
    
for j in tqdm(range(600)):
    ret, frame = cap.read()
    
    idx += np.argmin([abs(stamps[idx] -  time_stamp) , abs(stamps[idx + 1] -  time_stamp)])
    
    center = [None] * filtered_point_cloud_1[idx].shape[0]
    
    for i in range(filtered_point_cloud_1[idx].shape[0]):
        center[i] = (int(125 + 20.5*filtered_point_cloud_1[idx][i, 0]), int(735 - 20*filtered_point_cloud_1[idx][i, 1]))
        # 130 and 734 here are for translating the coordinate, 20 here is for scaling the resolution of the data to match the video resolution

    for i in range(len(center)):
        frame = cv2.circle(frame, center[i], radius=0, color=(0, 0, 255), thickness=-1) # circle function is for ploting the point cloud data on the picture frame
    detections = []
    for i in range(len(clustered_point_cloud[idx])):
        detections.append(Detection(box=np.array(clustered_point_cloud[idx][i][0]+clustered_point_cloud[idx][i][1])))
    tracker.step(detections=detections)
    tracks = tracker.active_tracks()
    for track in tracks:
        # print(track.id)
        # print(track.box)
        box = np.int64(track.box)
        
        # Deciding color based on size of boxes
        area = abs((box[0] - box[2]) * (box[1] - box[3]))
        if area < 2250:
            color = (255, 0, 0)
        else:
            color = (0,0,255)
            
        cv2.putText(frame,track.id, (int(box[0]),box[1]-5), cv2.FONT_HERSHEY_SIMPLEX, 0.25, 255)
        frame = cv2.rectangle(frame, pt1 = box[:2], pt2 = box[2:], color=color, thickness=2)

    #for i in range(len(clustered_point_cloud[idx])):
    #    frame = cv2.rectangle(frame, pt1 = clustered_point_cloud[idx][i][0], pt2 = clustered_point_cloud[idx][i][1], color=(255,0,0), thickness=1)
        
    out.write(frame)
    
    time_stamp += 1/15
        
out.release()

plt.imshow(frame)
# Out:
# 100%|██████████| 600/600 [00:16<00:00, 37.41it/s]

# %% [markdown]
# **Rough Work and Testing below this part:**

# %%
import numpy as np

from motpy import Detection, MultiObjectTracker
tracker = MultiObjectTracker(dt=1./15.)
idx = 0

for step in range(600):
    # let's simulate object movement by 1 unit (e.g. pixel)
    # object_box += 1
    idx += np.argmin([abs(stamps[idx] -  time_stamp) , abs(stamps[idx + 1] -  time_stamp)])
    
    detections = []
    for i in range(len(clustered_point_cloud[idx])):
        detections.append(Detection(box=np.array(clustered_point_cloud[idx][i][0]+clustered_point_cloud[idx][i][1])))
    tracker.step(detections=detections)

    # retrieve the active tracks from the tracker (you can customize
    # the hyperparameters of tracks filtering by passing extra arguments)
    tracks = tracker.active_tracks()
    print(step)
    print('MOT tracker tracks %d objects' % len(tracks))
    print('first track box: %s' % str(tracks[0].box))
    
for track in tracks:
    print(track.id)
    print(track.box)
    
print(track)
print()

# %%
# writing on the video

cap = cv2.VideoCapture('output1640b_transformed.mp4')
out = cv2.VideoWriter('synchronization_filtered_demo.mp4', cv2.VideoWriter_fourcc(*'mp4v'), 15, (832, 832))

counter = 0

for i in range(43):
    ret, frame = cap.read()
    
time_stamp = stamps[0]
idx = 0
    
for j in tqdm(range(600)):
    ret, frame = cap.read()
    
    idx += np.argmin([abs(stamps[idx] -  time_stamp) , abs(stamps[idx + 1] -  time_stamp)])
    
    center = [None] * filtered_point_cloud_1[idx].shape[0]
    
    for i in range(filtered_point_cloud_1[idx].shape[0]):
        center[i] = (int(125 + 20.5*filtered_point_cloud_1[idx][i, 0]), int(735 - 20*filtered_point_cloud_1[idx][i, 1]))        # 130 and 734 here are for translating the coordinate, 20 here is for scaling the resolution of the data to match the video resolution

    for i in range(len(center)):
        synchronization_image = cv2.circle(frame, center[i], radius=0, color=(0, 0, 255), thickness=-1) # circle function is for ploting the point cloud data on the picture frame

    out.write(synchronization_image)
    
    time_stamp += 1/15
            
out.release()
plt.imshow(synchronization_image)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:13<00:00, 45.89it/s]

# %%
import numpy as np
import matplotlib.pyplot as plt

x = cloud_arrays[1][:,0]
y = cloud_arrays[1][:,1]
z = cloud_arrays[1][:,2]

# Creating figure
fig = plt.figure(figsize = (10, 7))
ax = fig.add_subplot(projection='3d')

# Creating plot
ax.scatter( x, y, z, s = 0.001, color = "red")
ax.view_init(azim=0, elev=90)
plt.title("Original Point Cloud")
 
# show plot
plt.show()

x = filtered_point_cloud_1[1][:,0]
y = filtered_point_cloud_1[1][:,1]
z = filtered_point_cloud_1[1][:,2]

# Creating figure
fig = plt.figure(figsize = (10, 7))
ax = fig.add_subplot(projection = '3d')

# Creating plot
ax.scatter(x, y, z, s = 0.001, color = "red")
ax.view_init(azim=0, elev=90)
plt.title("Filtered Point Cloud")

    
# show plot
plt.show()

# %%
filtered_point_cloud_1 = []

for i in tqdm(range(len(filtered_point_cloud))):
    tmp = rotation_matrix(0, 0, -43).dot(filtered_point_cloud[i][:,0:3].T).T
    tmp = rotation_matrix(25, -5, 0).dot(tmp.T).T
    filtered_point_cloud_1.append(rotation_matrix(0, 0, 0).dot(tmp.T).T)
# Out:
# 100%|██████████| 600/600 [00:00<00:00, 3975.54it/s]

# %%
# Extracting frame

cap = cv2.VideoCapture('output1640b_transformed.mp4')
out = cv2.VideoWriter('synchronization_filtered_demo.mp4', cv2.VideoWriter_fourcc(*'mp4v'), 15, (832, 832))

counter = 0

for i in range(644):
    ret, frame = cap.read()  

center = [None] * filtered_point_cloud_1[idx].shape[0]

idx = 399
    
for i in range(filtered_point_cloud_1[idx].shape[0]):
    center[i] = (int(130 + 20.5*filtered_point_cloud_1[idx][i, 0]), int(735 - 20*filtered_point_cloud_1[idx][i, 1]))
    # 130 and 734 here are for translating the coordinate, 20 here is for scaling the resolution of the data to match the video resolution

for i in range(len(center)):
    synchronization_image = cv2.circle(frame, center[i], radius=0, color=(0, 0, 255), thickness=-1) # circle function is for ploting the point cloud data on the picture frame

plt.imshow(synchronization_image)

# %%
from sklearn.cluster import DBSCAN
import time
X = filtered_point_cloud[399][:,0:2]
print(X.shape)
start_time  = time.time()
db = DBSCAN(eps=0.6, min_samples=17).fit(X)
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print("Estimated number of clusters: %d" % n_clusters_)
print("Estimated number of noise points: %d" % n_noise_)
end_time = time.time()
print(end_time-start_time)
# Out:
# (7461, 2)
# Estimated number of clusters: 58
# Estimated number of noise points: 2953
# 0.05856776237487793

# %%
unique_labels = set(labels)
core_samples_mask = np.zeros_like(labels, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True

colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    
    col = [0, 0, 0, 1]
    
    if k == -1:
        # Black used for noise.
        col = [0,0,0,0]
        continue

    class_member_mask = labels == k

    xy = X[class_member_mask & core_samples_mask]
        
    if xy.shape[0]>0:
        plt.scatter(
            xy[:, 0],
            xy[:, 1],
            color = tuple(col),
    #         markeredgecolor="k",
            s = 0.1,
        )

    
        rect = patches.Rectangle((np.min(xy[:, 0]), np.min(xy[:, 1])), np.max(xy[:, 0])-np.min(xy[:, 0]), np.max(xy[:, 1])-np.min(xy[:, 1]), linewidth=1, edgecolor=tuple(col), facecolor='none')
        plt.gca().add_patch(rect)

plt.title(f"Estimated number of clusters: {n_clusters_}")
plt.show()
plt.show()

x = filtered_point_cloud[399][:,0]
y = filtered_point_cloud[399][:,1]
z = filtered_point_cloud[399][:,2]

# Creating figure
fig = plt.figure(figsize = (10, 7))
# ax = fig.add_subplot(projection = '3d')

# Creating plot
plt.scatter(x, y, s = 0.001, color = "red")
plt.title("Filtered Point Cloud")
 
# show plot
plt.show()

# %%
n, bins, patches = plt.hist(x=-1*cloud_arrays[0][:,0], bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.show()
print(idx)
# Out:
# 399

# %%
print(np.mean(cloud_arrays[0][:,0]), np.mean(cloud_arrays[0][:,1]), np.mean(cloud_arrays[0][:,2]))
# Out:
# 8.5318 -1.8553587 0.0097642215

# %%
# !conda install -c anaconda scikit-learn
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.3.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/rajatyagi/anaconda3/envs/myenv
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.4.26  |       hecd8cb5_0         132 KB  anaconda
#     certifi-2022.6.15          |  py310hecd8cb5_0         157 KB  anaconda
#     joblib-1.1.0               |     pyhd3eb1b0_0         211 KB  anaconda
#     scikit-learn-1.0.2         |  py310hc081a56_0         7.4 MB  anaconda
#     threadpoolctl-2.2.0        |     pyh0d69192_0          16 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         7.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   joblib             anaconda/noarch::joblib-1.1.0-pyhd3eb1b0_0
#   scikit-learn       anaconda/osx-64::scikit-learn-1.0.2-py310hc081a56_0
#   threadpoolctl      anaconda/noarch::threadpoolctl-2.2.0-pyh0d69192_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2022.12.~ --> anaconda::ca-certificates-2022.4.26-hecd8cb5_0
#   certifi            conda-forge/noarch::certifi-2022.12.7~ --> anaconda/osx-64::certifi-2022.6.15-py310hecd8cb5_0
#   openssl            conda-forge::openssl-1.1.1t-hfd90126_0 --> pkgs/main::openssl-1.1.1t-hca72f7f_0
#
#
# Proceed ([y]/n)? ^C
#
# CondaSystemExit:
# Operation aborted.  Exiting.

# %%
# %load_ext cython
