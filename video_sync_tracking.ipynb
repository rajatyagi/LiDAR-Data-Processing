# %%
# !pip install velodyne_decoder
# Out:
# Requirement already satisfied: velodyne_decoder in c:\users\mehme\anaconda3\envs\pytorch\lib\site-packages (2.3.0)
# Requirement already satisfied: dpkt in c:\users\mehme\anaconda3\envs\pytorch\lib\site-packages (from velodyne_decoder) (1.9.8)
# Requirement already satisfied: importlib-resources in c:\users\mehme\anaconda3\envs\pytorch\lib\site-packages (from velodyne_decoder) (5.12.0)
# Requirement already satisfied: numpy in c:\users\mehme\anaconda3\envs\pytorch\lib\site-packages (from velodyne_decoder) (1.21.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\mehme\anaconda3\envs\pytorch\lib\site-packages (from importlib-resources->velodyne_decoder) (3.15.0)

# %%
# !conda install -c menpo opencv

# %%
# !pip install motpy
# Out:
# Collecting motpy
#   Downloading motpy-0.0.10-py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy in c:\users\mehme\anaconda3\envs\pytorch\lib\site-packages (from motpy) (1.21.5)
# Requirement already satisfied: scipy in c:\users\mehme\anaconda3\envs\pytorch\lib\site-packages (from motpy) (1.7.3)
# Collecting filterpy
#   Downloading filterpy-1.4.5.zip (177 kB)
#      ------------------------------------- 178.0/178.0 kB 10.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: matplotlib in c:\users\mehme\anaconda3\envs\pytorch\lib\site-packages (from filterpy->motpy) (3.5.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mehme\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->filterpy->motpy) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mehme\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->filterpy->motpy) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mehme\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->filterpy->motpy) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mehme\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->filterpy->motpy) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mehme\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->filterpy->motpy) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mehme\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->filterpy->motpy) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mehme\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->filterpy->motpy) (1.4.4)
# Requirement already satisfied: typing-extensions in c:\users\mehme\anaconda3\envs\pytorch\lib\site-packages (from kiwisolver>=1.0.1->matplotlib->filterpy->motpy) (4.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\mehme\anaconda3\envs\pytorch\lib\site-packages (from python-dateutil>=2.7->matplotlib->filterpy->motpy) (1.16.0)
# Building wheels for collected packages: filterpy
#   Building wheel for filterpy (setup.py): started
#   Building wheel for filterpy (setup.py): finished with status 'done'
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110542 sha256=f9e1ab4fc1cf9e366449cca58f7261f4fadb465f9197a9df91a34106b65beeae
#   Stored in directory: c:\users\mehme\appdata\local\pip\cache\wheels\09\c1\ac\dbb7930f0a0761ab94991d016e089c683ded83e950b17cb51e
# Successfully built filterpy
# Installing collected packages: filterpy, motpy
# Successfully installed filterpy-1.4.5 motpy-0.0.10

# %%
import velodyne_decoder as vd
from datetime import datetime
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import math
import scipy.io
import numpy as np
import cv2
import matplotlib.patches as patches
from PIL import Image
from sklearn.cluster import DBSCAN
import time

# %%
# Functions

# Rotating the point clouds to be consistent with the video

def rotation_matrix(theta1, theta2, theta3, order='xyz'):
    c1 = np.cos(theta1 * np.pi / 180)
    s1 = np.sin(theta1 * np.pi / 180)
    c2 = np.cos(theta2 * np.pi / 180)
    s2 = np.sin(theta2 * np.pi / 180)
    c3 = np.cos(theta3 * np.pi / 180)
    s3 = np.sin(theta3 * np.pi / 180)
    matrix = np.array([[c2 * c3, -c2 * s3, s2],
                       [c1 * s3 + c3 * s1 * s2, c1 * c3 - s1 * s2 * s3, -c2 * s1],
                       [s1 * s3 - c1 * c3 * s2, c3 * s1 + c1 * s2 * s3, c1 * c2]])
    return matrix

# Converting to spherical co-ordinates 

# def cart2sph(x,y,z):
#     XsqPlusYsq = x**2 + y**2
#     r = math.sqrt(XsqPlusYsq + z**2)               # r
#     elev = math.atan2(z,math.sqrt(XsqPlusYsq))     # theta
#     az = math.atan2(y,x)                           # phi
#     return r, elev, az

def cart2sphA(xyz):
    ptsnew = np.zeros(xyz.shape)
    xy = xyz[:,0]**2 + xyz[:,1]**2
    ptsnew[:,0] = np.sqrt(xy + xyz[:,2]**2)
#     ptsnew[:,1] = np.arctan2(np.sqrt(xy), xyz[:,2]) # for elevation angle defined from Z-axis down
    ptsnew[:,1] = np.arctan2(xyz[:,2], np.sqrt(xy)) # for elevation angle defined from XY-plane up
    ptsnew[:,2] = np.arctan2(xyz[:,1], xyz[:,0])
    return ptsnew

# def cart2sphA(pts):
#     return np.array([cart2sph(x,y,z) for x,y,z in pts])

# Cropping point cloud data.

def cropPtCloud(ptCloud):
    
    xLim = [-150, 150]
    yLim = [-150, 150]
    zLim = [-10, 10]
        
    insideX = np.logical_and(ptCloud[:,0] < xLim[1], ptCloud[:,0] > xLim[0])
    insideY = np.logical_and(ptCloud[:,1] < yLim[1], ptCloud[:,1] > yLim[0])
    insideZ = np.logical_and(ptCloud[:,2] < zLim[1], ptCloud[:,2] > zLim[0])
    
    validIndices = np.logical_and(np.logical_and(insideX, insideY), insideZ);
            
    return ptCloud[validIndices,:]

# %%
# %%cython -a
#
# cdef extern from "math.h":
#     long double sqrt(long double xx)
#     long double atan2(long double a, double b)
#
# import numpy as np
# cimport numpy as np
# cimport cython
#
# ctypedef np.float64_t DTYPE_t
#
# @cython.boundscheck(False)
# @cython.wraparound(False)
# def appendSpherical(np.ndarray[DTYPE_t,ndim=2] xyz):
#     cdef np.ndarray[DTYPE_t,ndim=2] pts = np.empty((xyz.shape[0],6))
#     cdef long double XsqPlusYsq
#     for i in xrange(xyz.shape[0]):
#         pts[i,0] = xyz[i,0]
#         pts[i,1] = xyz[i,1]
#         pts[i,2] = xyz[i,2]
#         XsqPlusYsq = xyz[i,0]**2 + xyz[i,1]**2
#         pts[i,3] = sqrt(XsqPlusYsq + xyz[i,2]**2)
#         pts[i,4] = atan2(xyz[i,2],sqrt(XsqPlusYsq))
#         pts[i,5] = atan2(xyz[i,1],xyz[i,0])
#     return pts[:,3:]
# Out:
# UsageError: Cell magic `%%cython` not found.

# %%
# Reading the Point Cloud Data

config = vd.Config(model='VLP-32C', rpm=600)
pcap_file = './LiDAR_data.pcap'
stamps = []
cloud_arrays = []

# Reading the pcap file framewise
for stamp, pts in tqdm(vd.read_pcap(pcap_file, config)):
    points = np.zeros_like(pts)
    points[:,0] = -1*pts[:,1]
    points[:,1] = pts[:,0]
    points[:,2] = pts[:,2]
    cloud_arrays.append(points)
    stamps.append(stamp)
    
# # Converting 600 frames of Point Cloud data to spherical
# for i in tqdm(range(600)):
#     cloud_sph_arr.append(cart2sphA(cloud_arrays[i][:,0:3]))
# Out:
# 10627it [01:25, 124.06it/s]

# %%
# Load beams_elevation and range_thrld_matrix

range_thrld_matrix = scipy.io.loadmat('./range_thrld_matrix.mat')
range_thrld_matrix = range_thrld_matrix['range_thrld_matrix']
beams_elevation = scipy.io.loadmat('./beams_elevation_vlp32c.mat')
beams_elevation = beams_elevation['beams_elevation_vlp32c']

total_grid = 1800;
azimuth_unit = 360/total_grid;

filtered_point_cloud = []

for i in tqdm(range(600)):
    
    # Cropping the point cloud data and obtaining .
    cloud_array = cropPtCloud(cloud_arrays[i]);
    
    # Convert Cartesian to Spherical.
    cloud_sph_arr = cart2sphA(cloud_array[:,0:3])
    
    # Converting Azimuth from radians to degrees [0, 360]
    degree = cloud_sph_arr[:,2]
    degree = degree*180/3.14; # rad to deg
    degree[degree<0] = degree[degree<0] + 360
    
    # Assigning grids based on azimuth angle
    grids_idx = (np.floor(degree/azimuth_unit) + 1)%total_grid
    grids_idx[grids_idx == 0] = total_grid - 1  # deal with 1799 + 1 grid
    grids_idx[grids_idx == None] = 0 # LiDAR point NaN is set as 0
    grids_idx = grids_idx.astype(int)

    back_idxes = np.zeros(len(cloud_sph_arr))
    
    # Point cloud filtering process
    for pnt in (range(len(cloud_sph_arr))):
        
        r = cloud_sph_arr[pnt,0]
        elevation = cloud_sph_arr[pnt,1]
        grid_idx = grids_idx[pnt]

        if grid_idx == 0:
            back_idxes[pnt] = 1
            continue

        channel_num = np.argmin(abs(beams_elevation - elevation))

        if (r >= range_thrld_matrix[channel_num, grid_idx]):
            back_idxes[pnt] = 1
            
    filtered_point_cloud.append(cloud_array[back_idxes == 0, 0:3])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [01:53<00:00,  5.27it/s]

# %%
# Rotating the point clouds to be consistent with the video
filtered_point_cloud_1 = []
for i in tqdm(range(len(filtered_point_cloud))):
    tmp = rotation_matrix(0, 0, -43).dot(filtered_point_cloud[i][:,0:3].T).T
    tmp = rotation_matrix(25, -5, 0).dot(tmp.T).T
    filtered_point_cloud_1.append(rotation_matrix(0, 0, 0).dot(tmp.T).T)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 600/600 [00:00<00:00, 2248.22it/s]

# %%
# !pip install fast_dbscan
# Out:
# Collecting fast_dbscan
#   Downloading fast_dbscan-0.1.1.tar.gz (5.5 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [6 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 36, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\mehme\AppData\Local\Temp\pip-install-blk7lqiq\fast-dbscan_4a3d74a4d81d442eac0aa456cc9b9e99\setup.py", line 7, in <module>
#       from Cython.Distutils import build_ext
#   ModuleNotFoundError: No module named 'Cython'
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
labels = np.array(
        pcd.cluster_dbscan(eps=0.02, min_points=10, print_progress=True))

# %%
from sklearn.cluster import DBSCAN
import time
X = filtered_point_cloud[399][:,0:2]
print(X.shape)
start_time  = time.time()
db = DBSCAN(eps=0.06, min_samples=17, algorithm='ball_tree', n_jobs=1).fit(X)
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print("Estimated number of clusters: %d" % n_clusters_)
print("Estimated number of noise points: %d" % n_noise_)
end_time = time.time()
print(end_time-start_time)
# Out:
# (7461, 2)
# Estimated number of clusters: 4
# Estimated number of noise points: 6301
# 0.019582271575927734

# %%
# Applying DBSCAN

clustered_point_cloud = []
timings = []
for i in tqdm(range(len(filtered_point_cloud))):
    X = filtered_point_cloud_1[i][:,0:2]
    start_time  = time.time()
    db = DBSCAN(eps=1, min_samples=17, algorithm='ball_tree', n_jobs=1).fit(X)
    end_time = time.time()
    timings.append(end_time-start_time)
    labels = db.labels_

    # Number of clusters in labels, ignoring noise if present.
    n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
    n_noise_ = list(labels).count(-1)


    # Storing a rectangle for each cluster for later plotting on image
    rectangle_list = []
        
    for j in range(n_clusters_):
        class_member_mask = labels == j
        xy = X[class_member_mask, :]
        rectangle = [(int(125 + 20.5*np.min(xy[:, 0])), int(735 - 20*np.max(xy[:, 1]))), (int(125 + 20.5*np.max(xy[:, 0])), int(735 - 20*np.min(xy[:, 1])))]
        rectangle_list.append(rectangle)
    clustered_point_cloud.append(rectangle_list)
    
# print(rectangle_list)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:22<00:00, 26.68it/s]

# %%
np.mean(timings)
# Out:
# 0.0341460641225179

# %%
import numpy as np

from motpy import Detection, MultiObjectTracker
tracker = MultiObjectTracker(dt=1./15.)
idx = 0

for step in range(600):
    # let's simulate object movement by 1 unit (e.g. pixel)
    # object_box += 1
    idx += np.argmin([abs(stamps[idx] -  time_stamp) , abs(stamps[idx + 1] -  time_stamp)])
    
    detections = []
    for i in range(len(clustered_point_cloud[idx])):
        detections.append(Detection(box=np.array(clustered_point_cloud[idx][i][0]+clustered_point_cloud[idx][i][1])))
    tracker.step(detections=detections)

    # retrieve the active tracks from the tracker (you can customize
    # the hyperparameters of tracks filtering by passing extra arguments)
    tracks = tracker.active_tracks()
    print(step)
    print('MOT tracker tracks %d objects' % len(tracks))
    print('first track box: %s' % str(tracks[0].box))
# Out:
# 0
# MOT tracker tracks 46 objects
# first track box: [ 100.  736.  124. 1079.]
# 1
# MOT tracker tracks 56 objects
# first track box: [ 104.99504074  738.99702444  123.99998634 1078.9999918 ]
# 2
# MOT tracker tracks 55 objects
# first track box: [  98.87280751  735.57057956  123.37317846 1055.40431132]
# 3
# MOT tracker tracks 57 objects
# first track box: [  96.70916215  729.57842063  122.58331908 1092.62040982]
# 4
# MOT tracker tracks 55 objects
# first track box: [  93.85237822  737.7494458   122.59005688 1065.94193669]
# 5
# MOT tracker tracks 56 objects
# first track box: [  96.02775671  734.81221624  122.2575033  1063.7444499 ]
# 6
# MOT tracker tracks 59 objects
# first track box: [  92.37021606  729.59742163  123.88597515 1081.49372924]
# 7
# MOT tracker tracks 58 objects
# first track box: [  98.25962848  746.8169297   120.14211326 1047.50775996]
# 8
# MOT tracker tracks 57 objects
# first track box: [  94.44482375  730.7885053   122.84752033 1065.65751169]
# 9
# MOT tracker tracks 63 objects
# first track box: [  97.44979945  732.06325211  121.81927471 1067.0522591 ]
# 10
# MOT tracker tracks 67 objects
# first track box: [  96.70012825  729.42905653  122.56329425 1072.67285204]
# 11
# MOT tracker tracks 64 objects
# first track box: [  96.3501309   731.09765506  123.25472754 1073.20203465]
# 12
# MOT tracker tracks 63 objects
# first track box: [  97.35704913  743.22689872  122.51688329 1051.34070631]
# 13
# MOT tracker tracks 62 objects
# first track box: [  99.95431626  730.92134551  121.30341045 1067.32936955]
# 14
# MOT tracker tracks 61 objects
# first track box: [ 100.65821863  726.15655845  121.68751469 1078.68023601]
# 15
# MOT tracker tracks 61 objects
# first track box: [  98.73367315  731.1439364   123.40045082 1079.5235644 ]
# 16
# MOT tracker tracks 64 objects
# first track box: [  99.92471998  731.05912638  123.06459633 1082.75530398]
# 17
# MOT tracker tracks 64 objects
# first track box: [  96.57065138  734.90228157  125.07886853 1078.63206668]
# 18
# MOT tracker tracks 62 objects
# first track box: [ 100.10550441  732.56586426  122.65167541 1083.87182604]
# 19
# MOT tracker tracks 61 objects
# first track box: [ 101.15528969  743.81365607  122.28504469 1067.35693895]
# 20
# MOT tracker tracks 64 objects
# first track box: [  99.17777967  734.70513124  123.85298787 1076.98839911]
# 21
# MOT tracker tracks 65 objects
# first track box: [  95.37013692  746.93930405  125.83935902 1055.98420376]
# 22
# MOT tracker tracks 64 objects
# first track box: [  99.20479884  729.68728975  122.83161758 1076.25032885]
# 23
# MOT tracker tracks 63 objects
# first track box: [ 100.19124522  733.78985488  122.3277682  1074.34062654]
# 24
# MOT tracker tracks 61 objects
# first track box: [  98.15053901  728.29117917  123.82631518 1083.91075636]
# 25
# MOT tracker tracks 57 objects
# first track box: [  99.49641046  747.25974332  122.72096218 1056.50774922]
# 26
# MOT tracker tracks 59 objects
# first track box: [  98.54860526  729.85247753  123.39960926 1078.26472091]
# 27
# MOT tracker tracks 60 objects
# first track box: [ 100.09472452  734.72502758  122.33398139 1072.68274552]
# 28
# MOT tracker tracks 61 objects
# first track box: [  99.25794867  733.16109954  123.11018673 1074.82187035]
# 29
# MOT tracker tracks 59 objects
# first track box: [  99.16123115  736.44438218  123.14883094 1071.08727573]
# 30
# MOT tracker tracks 58 objects
# first track box: [ 102.59270703  726.8586495   121.09518771 1088.39499476]
# 31
# MOT tracker tracks 56 objects
# first track box: [ 101.68525392  733.09737526  122.47566155 1084.06550785]
# 32
# MOT tracker tracks 54 objects
# first track box: [  99.47343069  745.59087351  124.12016079 1064.52540679]
# 33
# MOT tracker tracks 52 objects
# first track box: [ 101.3630338   729.50277444  122.66906818 1085.14047179]
# 34
# MOT tracker tracks 54 objects
# first track box: [ 100.76976942  726.53185061  123.62761146 1094.41048327]
# 35
# MOT tracker tracks 54 objects
# first track box: [  99.12142882  732.77390063  124.85773824 1090.68683784]
# 36
# MOT tracker tracks 55 objects
# first track box: [ 100.54136273  736.61772645  123.77099441 1089.11394142]
# 37
# MOT tracker tracks 56 objects
# first track box: [  99.39128017  736.35309435  124.24271047 1090.22689638]
# 38
# MOT tracker tracks 54 objects
# first track box: [ 100.17690137  733.08871984  123.33227381 1097.15500689]
# 39
# MOT tracker tracks 56 objects
# first track box: [  98.69888866  738.66952627  124.4601669  1090.76605191]
# 40
# MOT tracker tracks 55 objects
# first track box: [ 100.16939515  742.0146989   123.40112222 1084.86200152]
# 41
# MOT tracker tracks 54 objects
# first track box: [ 100.45537696  740.6804834   123.47482355 1085.49982857]
# 42
# MOT tracker tracks 56 objects
# first track box: [ 102.68927764  736.82278878  122.02659047 1089.13626645]
# 43
# MOT tracker tracks 55 objects
# first track box: [  97.0681234   733.86638753  126.17330838 1092.30525313]
# 44
# MOT tracker tracks 53 objects
# first track box: [ 102.70099433  744.21135721  121.63294386 1076.59795298]
# 45
# MOT tracker tracks 53 objects
# first track box: [  98.98486394  743.15823511  124.39171161 1071.52635918]
# 46
# MOT tracker tracks 53 objects
# first track box: [ 102.33501642  749.06098449  121.87268046 1055.10596275]
# 47
# MOT tracker tracks 56 objects
# first track box: [ 103.18155396  729.95806913  122.22667484 1078.10151374]
# 48
# MOT tracker tracks 58 objects
# first track box: [ 101.74714822  734.46353145  123.49917413 1071.48261195]
# 49
# MOT tracker tracks 61 objects
# first track box: [  99.24249222  726.23995961  124.88600132 1086.14355543]
# 50
# MOT tracker tracks 61 objects
# first track box: [ 101.1343587   736.71596668  123.44012277 1074.72196162]
# 51
# MOT tracker tracks 59 objects
# first track box: [  96.03309714  747.07598835  126.30347497 1056.67801817]
# 52
# MOT tracker tracks 59 objects
# first track box: [  96.55997392  762.65175644  123.83442474 1019.48573128]
# 53
# MOT tracker tracks 58 objects
# first track box: [  97.49035921  726.35999202  122.68123161 1058.46460137]
# 54
# MOT tracker tracks 57 objects
# first track box: [  99.81560478  721.09646318  121.1673037  1069.59467811]
# 55
# MOT tracker tracks 63 objects
# first track box: [  98.04156108  738.46295361  122.73539486 1046.19725346]
# 56
# MOT tracker tracks 60 objects
# first track box: [  99.55843656  718.70026824  121.78450368 1074.31411935]
# 57
# MOT tracker tracks 62 objects
# first track box: [ 100.15910945  717.62913057  122.17808105 1085.50576205]
# 58
# MOT tracker tracks 62 objects
# first track box: [ 103.35401333  768.00026028  119.85912673 1013.23521623]
# 59
# MOT tracker tracks 57 objects
# first track box: [  98.66812386  739.08437314  123.87131092 1037.23671811]
# 60
# MOT tracker tracks 60 objects
# first track box: [  98.0054464   718.85128659  123.93857769 1065.41629991]
# 61
# MOT tracker tracks 64 objects
# first track box: [ 102.67377776  747.74965065  120.42344807 1025.09108296]
# 62
# MOT tracker tracks 67 objects
# first track box: [ 100.87155706  719.06164687  122.51486847 1064.79628368]
# 63
# MOT tracker tracks 66 objects
# first track box: [ 103.13745232  729.81065761  121.4431998  1058.38287239]
# 64
# MOT tracker tracks 63 objects
# first track box: [ 101.4784514   728.78987378  123.16842893 1063.25045265]
# 65
# MOT tracker tracks 67 objects
# first track box: [  99.28048498  729.64037637  124.91878696 1065.51118781]
# 66
# MOT tracker tracks 66 objects
# first track box: [ 100.64061656  728.13687251  123.86202344 1074.20290859]
# 67
# MOT tracker tracks 65 objects
# first track box: [  98.89517149  725.18436959  124.66199135 1084.01502832]
# 68
# MOT tracker tracks 63 objects
# first track box: [ 101.25718559  747.35844677  122.65721815 1056.87592733]
# 69
# MOT tracker tracks 65 objects
# first track box: [  99.86213793  745.86742524  123.6439481  1052.16261297]
# 70
# MOT tracker tracks 64 objects
# first track box: [ 101.31420782  734.9193711   122.54765793 1064.76221768]
# 71
# MOT tracker tracks 64 objects
# first track box: [ 101.43678979  766.5755259   121.54030119 1011.36691772]
# 72
# MOT tracker tracks 63 objects
# first track box: [ 103.20773676  725.99859287  121.38426389 1060.75690517]
# 73
# MOT tracker tracks 62 objects
# first track box: [ 100.62763077  738.18677589  123.22284388 1044.76802013]
# 74
# MOT tracker tracks 62 objects
# first track box: [  98.85879115  720.93810679  124.5730607  1070.04263474]
# 75
# MOT tracker tracks 63 objects
# first track box: [ 100.61598317  725.34463134  122.92768548 1073.43732356]
# 76
# MOT tracker tracks 62 objects
# first track box: [ 101.62455856  727.03454123  122.7346369  1077.79055933]
# 77
# MOT tracker tracks 60 objects
# first track box: [ 101.4510235   728.80851149  123.37634108 1081.62019605]
# 78
# MOT tracker tracks 64 objects
# first track box: [  99.30488196  725.30050058  124.96293373 1093.85805342]
# 79
# MOT tracker tracks 65 objects
# first track box: [ 101.54640743  751.71539305  122.93731215 1060.21699711]
# 80
# MOT tracker tracks 65 objects
# first track box: [ 101.8160364   734.68844665  122.84884121 1082.12197205]
# 81
# MOT tracker tracks 66 objects
# first track box: [ 101.32817092  749.36831987  123.24700369 1058.84543031]
# 82
# MOT tracker tracks 65 objects
# first track box: [  99.17682383  738.90189195  124.83433139 1068.09568639]
# 83
# MOT tracker tracks 66 objects
# first track box: [  98.19527353  729.58407289  125.08261127 1080.58625095]
# 84
# MOT tracker tracks 68 objects
# first track box: [  98.16630666  729.00389661  124.24077224 1084.58447831]
# 85
# MOT tracker tracks 68 objects
# first track box: [  99.80024437  730.04913347  123.05825419 1087.84609536]
# 86
# MOT tracker tracks 67 objects
# first track box: [ 100.70234207  737.18029931  122.80791453 1080.50598378]
# 87
# MOT tracker tracks 69 objects
# first track box: [ 100.80071693  734.6047268   122.80957659 1086.79285614]
# 88
# MOT tracker tracks 67 objects
# first track box: [ 100.51040794  741.82921093  123.42723123 1076.43948291]
# 89
# MOT tracker tracks 68 objects
# first track box: [  99.22104953  750.95232087  124.04622889 1057.52114153]
# 90
# MOT tracker tracks 68 objects
# first track box: [  98.84895822  745.90781091  123.83428723 1054.70378581]
# 91
# MOT tracker tracks 68 objects
# first track box: [  99.16986776  728.68636066  123.25255679 1076.14458972]
# 92
# MOT tracker tracks 67 objects
# first track box: [ 100.25618915  731.5372835   122.43096886 1073.99533927]
# 93
# MOT tracker tracks 63 objects
# first track box: [ 102.42877027  737.78370895  121.69519848 1066.99703213]
# 94
# MOT tracker tracks 65 objects
# first track box: [ 103.51574055  735.19203038  121.62201948 1069.70641121]
# 95
# MOT tracker tracks 62 objects
# first track box: [ 101.92616261  732.4385389   123.59940069 1073.81034412]
# 96
# MOT tracker tracks 61 objects
# first track box: [ 103.42522329  725.64394268  122.64956201 1086.82889988]
# 97
# MOT tracker tracks 61 objects
# first track box: [ 102.02019323  733.03600878  123.78725913 1080.31033368]
# 98
# MOT tracker tracks 61 objects
# first track box: [ 102.35969404  750.0236983   123.42406638 1053.9909699 ]
# 99
# MOT tracker tracks 65 objects
# first track box: [ 101.21283842  745.73586743  124.05040013 1051.56528043]
# 100
# MOT tracker tracks 68 objects
# first track box: [ 101.48083576  730.01519946  123.55112412 1069.89583574]
# 101
# MOT tracker tracks 66 objects
# first track box: [ 103.71744012  732.84144582  122.0590196  1067.33495009]
# 102
# MOT tracker tracks 63 objects
# first track box: [ 103.03882718  733.60735458  122.89965217 1068.56484935]
# 103
# MOT tracker tracks 65 objects
# first track box: [ 100.96708042  722.25697722  124.61971996 1088.4001228 ]
# 104
# MOT tracker tracks 67 objects
# first track box: [ 102.14171536  747.91418672  123.36432545 1054.38101363]
# 105
# MOT tracker tracks 65 objects
# first track box: [  98.97943278  733.40863092  125.49459296 1069.67843998]
# 106
# MOT tracker tracks 61 objects
# first track box: [  96.91493734  725.5089974   125.70640904 1082.60147485]
# 107
# MOT tracker tracks 62 objects
# first track box: [ 100.64125361  732.31837276  122.29511561 1080.16533566]
# 108
# MOT tracker tracks 61 objects
# first track box: [ 100.75539282  733.41983441  122.72634485 1082.32307129]
# 109
# MOT tracker tracks 63 objects
# first track box: [ 101.32936451  750.21766943  122.41084701 1057.98595881]
# 110
# MOT tracker tracks 63 objects
# first track box: [  99.75363003  730.7226486   123.50870741 1080.84287341]
# 111
# MOT tracker tracks 62 objects
# first track box: [ 100.59362493  731.98848297  122.74091141 1081.99857227]
# 112
# MOT tracker tracks 65 objects
# first track box: [ 100.6993735   732.33507356  122.71173381 1084.16807982]
# 113
# MOT tracker tracks 66 objects
# first track box: [ 100.74374281  733.40599235  122.74478009 1084.47589842]
# 114
# MOT tracker tracks 67 objects
# first track box: [  99.7276399   772.60173541  122.64380673 1019.17450667]
# 115
# MOT tracker tracks 69 objects
# first track box: [  98.19289597  730.06751583  123.93410002 1064.0592421 ]
# 116
# MOT tracker tracks 68 objects
# first track box: [  99.47260708  723.76308045  122.70264952 1077.91614134]
# 117
# MOT tracker tracks 68 objects
# first track box: [ 100.18703336  741.2529965   122.29025879 1054.04225116]
# 118
# MOT tracker tracks 68 objects
# first track box: [  98.30333166  725.69374365  123.9763135  1074.4031694 ]
# 119
# MOT tracker tracks 69 objects
# first track box: [  99.56713758  727.25369672  122.79145479 1077.14539145]
# 120
# MOT tracker tracks 72 objects
# first track box: [  98.55574396  730.88934279  123.40672828 1075.38377509]
# 121
# MOT tracker tracks 71 objects
# first track box: [ 100.96904194  754.79662949  121.3761376  1040.20901624]
# 122
# MOT tracker tracks 70 objects
# first track box: [ 100.41198751  741.70698292  122.27831063 1047.81142552]
# 123
# MOT tracker tracks 71 objects
# first track box: [  98.19419799  720.33648098  123.84729893 1076.7296339 ]
# 124
# MOT tracker tracks 70 objects
# first track box: [  99.48706613  741.61160881  122.70971494 1050.00845357]
# 125
# MOT tracker tracks 69 objects
# first track box: [  97.92929574  730.89674555  123.69621982 1062.74812321]
# 126
# MOT tracker tracks 70 objects
# first track box: [ 100.46517355  726.04639443  121.86521486 1075.43943789]
# 127
# MOT tracker tracks 70 objects
# first track box: [ 100.38279033  743.94906424  122.33244167 1051.7584583 ]
# 128
# MOT tracker tracks 70 objects
# first track box: [ 100.52709749  733.21133689  122.52287222 1063.18125599]
# 129
# MOT tracker tracks 72 objects
# first track box: [ 101.48384972  724.36992321  122.56741535 1079.10155295]
# 130
# MOT tracker tracks 71 objects
# first track box: [  99.40346464  723.45910404  124.07479662 1087.59738018]
# 131
# MOT tracker tracks 70 objects
# first track box: [ 101.98131345  766.89939228  121.45725286 1024.6457416 ]
# 132
# MOT tracker tracks 70 objects
# first track box: [  95.72650683  736.71514052  125.75940516 1054.23904   ]
# 133
# MOT tracker tracks 71 objects
# first track box: [  96.98259092  728.25584261  124.23711241 1066.36964338]
# 134
# MOT tracker tracks 69 objects
# first track box: [  99.64223807  723.7189439   122.08319866 1077.3018504 ]
# 135
# MOT tracker tracks 67 objects
# first track box: [ 102.38287922  726.77746928  120.75556559 1079.82638692]
# 136
# MOT tracker tracks 69 objects
# first track box: [  98.79055201  735.05104475  124.1504662  1071.56571383]
# 137
# MOT tracker tracks 70 objects
# first track box: [  98.16840752  730.50913999  124.11469138 1080.29352788]
# 138
# MOT tracker tracks 71 objects
# first track box: [ 101.3200803   738.04803988  121.81909373 1072.45658935]
# 139
# MOT tracker tracks 70 objects
# first track box: [ 100.76639878  732.19192609  122.64043566 1083.63172753]
# 140
# MOT tracker tracks 69 objects
# first track box: [ 103.12944349  748.92319531  121.4545535  1058.7365133 ]
# 141
# MOT tracker tracks 69 objects
# first track box: [ 101.4727603   735.62968547  123.16436274 1072.18033278]
# 142
# MOT tracker tracks 68 objects
# first track box: [  99.94826319  746.64761117  123.75454196 1053.37926855]
# 143
# MOT tracker tracks 70 objects
# first track box: [ 100.83685486  731.73992302  122.98843817 1069.86411627]
# 144
# MOT tracker tracks 69 objects
# first track box: [ 103.26496507  728.70948926  121.61336684 1078.62894876]
# 145
# MOT tracker tracks 70 objects
# first track box: [ 104.11464988  734.20488327  122.14388784 1075.03732646]
# 146
# MOT tracker tracks 69 objects
# first track box: [ 102.16650745  730.60729977  123.83328024 1081.67011598]
# 147
# MOT tracker tracks 69 objects
# first track box: [ 101.30561297  726.95458095  124.19372825 1091.70104925]
# 148
# MOT tracker tracks 68 objects
# first track box: [ 101.26180114  730.78412737  124.25241175 1092.0985318 ]
# 149
# MOT tracker tracks 66 objects
# first track box: [  99.86169094  750.28565894  124.69306255 1063.6758951 ]
# 150
# MOT tracker tracks 66 objects
# first track box: [ 100.51608124  737.49185348  123.66977034 1076.17483611]
# 151
# MOT tracker tracks 67 objects
# first track box: [ 101.00408476  728.92218202  123.1009026  1088.96541287]
# 152
# MOT tracker tracks 73 objects
# first track box: [ 100.43863761  748.60051525  123.36284237 1060.96799447]
# 153
# MOT tracker tracks 74 objects
# first track box: [ 100.85266244  734.21860202  122.93022191 1078.31223336]
# 154
# MOT tracker tracks 70 objects
# first track box: [  99.15272368  732.0141554   123.90747184 1083.35065123]
# 155
# MOT tracker tracks 70 objects
# first track box: [ 100.70223972  733.544664    122.93341879 1086.40506237]
# 156
# MOT tracker tracks 70 objects
# first track box: [ 100.24976228  735.70084387  123.18524266 1084.10872955]
# 157
# MOT tracker tracks 71 objects
# first track box: [ 100.13675571  734.01638048  123.13134121 1089.3792486 ]
# 158
# MOT tracker tracks 71 objects
# first track box: [ 100.64368     754.06276821  122.72714583 1057.79275233]
# 159
# MOT tracker tracks 71 objects
# first track box: [ 100.73123133  747.30786022  122.7382358  1055.86559934]
# 160
# MOT tracker tracks 70 objects
# first track box: [  98.70991944  729.14639572  124.37482639 1076.58463198]
# 161
# MOT tracker tracks 68 objects
# first track box: [ 102.7722493   726.80961354  121.41548996 1083.92326803]
# 162
# MOT tracker tracks 71 objects
# first track box: [ 102.39407703  744.64342052  122.28021749 1058.59720862]
# 163
# MOT tracker tracks 72 objects
# first track box: [ 103.36451011  727.97977697  122.4388752  1079.53516996]
# 164
# MOT tracker tracks 73 objects
# first track box: [ 104.21909997  727.63553004  122.30926092 1084.17861744]
# 165
# MOT tracker tracks 74 objects
# first track box: [ 103.06691707  734.05237883  123.82272274 1078.18891766]
# 166
# MOT tracker tracks 74 objects
# first track box: [ 102.85588475  737.79689841  123.83539191 1072.64755894]
# 167
# MOT tracker tracks 71 objects
# first track box: [ 104.23691617  737.05907643  122.48695705 1072.04654383]
# 168
# MOT tracker tracks 69 objects
# first track box: [ 102.85872934  731.63384037  123.62795217 1080.37398538]
# 169
# MOT tracker tracks 67 objects
# first track box: [ 100.90668951  736.05042456  124.63556199 1075.86781964]
# 170
# MOT tracker tracks 64 objects
# first track box: [ 101.52005621  737.25388039  123.66514357 1072.65815723]
# 171
# MOT tracker tracks 66 objects
# first track box: [ 102.58594437  731.71993497  122.76596056 1080.49505871]
# 172
# MOT tracker tracks 68 objects
# first track box: [ 103.31968695  732.9778476   122.41871416 1081.95897594]
# 173
# MOT tracker tracks 65 objects
# first track box: [ 102.13953853  737.14730552  122.98000849 1076.06884419]
# 174
# MOT tracker tracks 68 objects
# first track box: [ 103.76688945  748.79269236  122.00526231 1055.72331546]
# 175
# MOT tracker tracks 70 objects
# first track box: [ 100.11957477  741.71727869  124.55213755 1057.8722544 ]
# 176
# MOT tracker tracks 68 objects
# first track box: [ 102.26762731  741.96049428  122.63960894 1051.5609414 ]
# 177
# MOT tracker tracks 67 objects
# first track box: [ 100.81350526  729.86502008  123.59296139 1065.48172345]
# 178
# MOT tracker tracks 65 objects
# first track box: [ 101.65361104  722.15828677  122.80294338 1082.86027457]
# 179
# MOT tracker tracks 71 objects
# first track box: [ 101.17259631  725.87316776  123.10120809 1084.09991916]
# 180
# MOT tracker tracks 72 objects
# first track box: [  98.7566668   736.93164555  124.41499502 1071.13260022]
# 181
# MOT tracker tracks 69 objects
# first track box: [  98.36760705  733.49388461  124.33893388 1076.6715466 ]
# 182
# MOT tracker tracks 68 objects
# first track box: [  97.92739685  727.53709011  123.92499059 1087.04143563]
# 183
# MOT tracker tracks 70 objects
# first track box: [ 102.52822779  754.85767439  120.2833078  1047.026175  ]
# 184
# MOT tracker tracks 71 objects
# first track box: [  99.50463234  732.35039767  122.9805573  1071.08460721]
# 185
# MOT tracker tracks 74 objects
# first track box: [ 100.28706541  728.43761304  122.41092535 1080.24042481]
# 186
# MOT tracker tracks 78 objects
# first track box: [ 100.44594373  745.427725    122.45633808 1057.10366647]
# 187
# MOT tracker tracks 78 objects
# first track box: [  99.96899352  725.94359057  122.8859456  1085.55254423]
# 188
# MOT tracker tracks 79 objects
# first track box: [ 102.80179356  734.51573292  121.21442525 1080.74171948]
# 189
# MOT tracker tracks 75 objects
# first track box: [ 103.49757213  734.01943819  121.53220027 1083.70272217]
# 190
# MOT tracker tracks 74 objects
# first track box: [ 103.60874337  732.61099142  122.52772915 1088.08089124]
# 191
# MOT tracker tracks 74 objects
# first track box: [ 102.30755008  735.65567398  124.0489907  1087.94686872]
# 192
# MOT tracker tracks 75 objects
# first track box: [ 100.87399426  752.17556925  124.68445547 1061.14425657]
# 193
# MOT tracker tracks 75 objects
# first track box: [ 100.66410603  733.63436437  124.64819989 1081.1070875 ]
# 194
# MOT tracker tracks 75 objects
# first track box: [ 101.11911518  731.17372585  124.20170055 1086.45811492]
# 195
# MOT tracker tracks 76 objects
# first track box: [ 101.15497758  735.94701969  124.16190817 1082.72616763]
# 196
# MOT tracker tracks 79 objects
# first track box: [ 102.64489652  734.88974738  122.89723879 1084.61945278]
# 197
# MOT tracker tracks 78 objects
# first track box: [ 104.58557542  733.63684277  121.85851269 1088.19455851]
# 198
# MOT tracker tracks 79 objects
# first track box: [ 103.60208478  735.51885082  123.37322908 1086.8174151 ]
# 199
# MOT tracker tracks 76 objects
# first track box: [ 100.59110661  751.9872177   125.15229991 1059.95652348]
# 200
# MOT tracker tracks 73 objects
# first track box: [ 100.08264849  734.02034047  125.04582374 1079.57703571]
# 201
# MOT tracker tracks 72 objects
# first track box: [ 104.17701269  735.50208145  121.84528408 1080.54879944]
# 202
# MOT tracker tracks 74 objects
# first track box: [  97.12827825  749.30007286  126.09339691 1056.74472234]
# 203
# MOT tracker tracks 74 objects
# first track box: [ 100.6340641   747.70286751  122.30249859 1050.15978368]
# 204
# MOT tracker tracks 76 objects
# first track box: [  98.76202575  728.72015684  123.48244005 1071.98209158]
# 205
# MOT tracker tracks 72 objects
# first track box: [  97.77296426  724.14993152  123.66558115 1080.91310989]
# 206
# MOT tracker tracks 71 objects
# first track box: [ 101.19618566  752.35242238  120.77461557 1039.71048474]
# 207
# MOT tracker tracks 73 objects
# first track box: [ 103.10605493  733.01892484  120.32243733 1062.18864354]
# 208
# MOT tracker tracks 77 objects
# first track box: [ 100.96404717  729.86395209  122.56260494 1067.12291297]
# 209
# MOT tracker tracks 77 objects
# first track box: [ 100.82522349  725.73801841  122.79153437 1075.58486743]
# 210
# MOT tracker tracks 73 objects
# first track box: [ 100.85031699  730.87406716  122.84748979 1071.70041686]
# 211
# MOT tracker tracks 77 objects
# first track box: [  99.39140129  726.87373151  124.13940338 1081.60035549]
# 212
# MOT tracker tracks 77 objects
# first track box: [ 100.69716226  729.63127711  122.92777519 1082.77617577]
# 213
# MOT tracker tracks 75 objects
# first track box: [ 102.81514836  741.09138039  122.0862621  1068.45330639]
# 214
# MOT tracker tracks 77 objects
# first track box: [ 100.02801403  730.17713435  124.54724465 1085.60598053]
# 215
# MOT tracker tracks 79 objects
# first track box: [ 101.72875099  741.63302506  123.02408559 1073.76701934]
# 216
# MOT tracker tracks 79 objects
# first track box: [ 103.32877563  738.13539724  122.52140061 1076.55920055]
# 217
# MOT tracker tracks 79 objects
# first track box: [  96.38097916  740.79801843  127.30618147 1071.50494583]
# 218
# MOT tracker tracks 80 objects
# first track box: [ 100.4749163   725.57689307  123.22392122 1094.11156946]
# 219
# MOT tracker tracks 78 objects
# first track box: [ 100.2500202   751.35504271  123.22895664 1058.93864718]
# 220
# MOT tracker tracks 78 objects
# first track box: [  99.91036737  752.35117213  122.90859971 1046.57503138]
# 221
# MOT tracker tracks 79 objects
# first track box: [  99.86728035  736.18164529  122.86713201 1063.1793038 ]
# 222
# MOT tracker tracks 79 objects
# first track box: [  94.88213307  722.06787062  126.12683867 1085.71086544]
# 223
# MOT tracker tracks 76 objects
# first track box: [  99.90977053  734.20456034  121.76950845 1075.27260581]
# 224
# MOT tracker tracks 80 objects
# first track box: [  98.88074565  735.85004922  122.70113439 1073.19144048]
# 225
# MOT tracker tracks 82 objects
# first track box: [  99.58400355  731.98061345  122.65285075 1080.00222048]
# 226
# MOT tracker tracks 80 objects
# first track box: [ 102.55772801  739.03491604  120.98310676 1072.37945278]
# 227
# MOT tracker tracks 78 objects
# first track box: [ 103.32138955  737.64702928  121.35708743 1072.50810244]
# 228
# MOT tracker tracks 80 objects
# first track box: [ 100.36095994  747.76094805  123.86043441 1054.350816  ]
# 229
# MOT tracker tracks 78 objects
# first track box: [ 100.49893244  726.8283864   123.54084844 1081.43011675]
# 230
# MOT tracker tracks 75 objects
# first track box: [ 101.00941708  735.51545294  123.0968549  1071.24435462]
# 231
# MOT tracker tracks 75 objects
# first track box: [ 100.49575638  726.7510543   123.41917397 1085.63029825]
# 232
# MOT tracker tracks 72 objects
# first track box: [  99.79568136  741.67292169  123.70533433 1066.76783585]
# 233
# MOT tracker tracks 76 objects
# first track box: [  99.91113066  754.22944089  122.98746893 1041.678135  ]
# 234
# MOT tracker tracks 78 objects
# first track box: [ 101.07905975  727.45313213  122.25330651 1073.11989275]
# 235
# MOT tracker tracks 80 objects
# first track box: [ 101.35107913  742.36301191  122.36570196 1051.69185507]
# 236
# MOT tracker tracks 80 objects
# first track box: [ 102.91808643  726.20690582  122.08715401 1072.79377351]
# 237
# MOT tracker tracks 79 objects
# first track box: [  97.53935662  736.21481135  125.71434263 1059.36206683]
# 238
# MOT tracker tracks 80 objects
# first track box: [  99.61841655  732.84488976  123.0527025  1063.18588574]
# 239
# MOT tracker tracks 84 objects
# first track box: [ 102.6934495   743.23634833  121.14949596 1048.53081064]
# 240
# MOT tracker tracks 84 objects
# first track box: [ 103.41594053  737.98493335  121.45421204 1054.00260209]
# 241
# MOT tracker tracks 86 objects
# first track box: [ 102.14343972  731.02491667  122.89489082 1065.3479951 ]
# 242
# MOT tracker tracks 84 objects
# first track box: [  96.3199823   728.00888125  126.45992186 1073.94503124]
# 243
# MOT tracker tracks 82 objects
# first track box: [  99.55836672  731.4108646   123.15755199 1073.74118716]
# 244
# MOT tracker tracks 81 objects
# first track box: [ 100.05158941  736.4494165   123.10187316 1070.23241919]
# 245
# MOT tracker tracks 82 objects
# first track box: [ 102.00307606  735.59596027  122.25905653 1072.32598916]
# 246
# MOT tracker tracks 81 objects
# first track box: [ 101.54873049  743.95434195  122.48629221 1058.02969134]
# 247
# MOT tracker tracks 82 objects
# first track box: [  99.92348753  733.37900153  123.66648704 1070.28731945]
# 248
# MOT tracker tracks 80 objects
# first track box: [  99.03322613  728.98238885  123.92773838 1079.71589162]
# 249
# MOT tracker tracks 78 objects
# first track box: [  99.52943231  738.01950512  123.60449997 1069.75946517]
# 250
# MOT tracker tracks 77 objects
# first track box: [  97.91181637  730.88157514  124.66635541 1079.34918862]
# 251
# MOT tracker tracks 77 objects
# first track box: [  98.13948403  731.10651969  124.20280511 1081.89400126]
# 252
# MOT tracker tracks 81 objects
# first track box: [  98.9892046   745.98871266  123.16235895 1062.15984631]
# 253
# MOT tracker tracks 79 objects
# first track box: [  99.80926756  731.45557575  122.90771893 1079.53272973]
# 254
# MOT tracker tracks 76 objects
# first track box: [  99.29085342  750.3755603   123.21519527 1053.49412571]
# 255
# MOT tracker tracks 80 objects
# first track box: [ 100.89958331  730.00037353  122.14499471 1077.89823294]
# 256
# MOT tracker tracks 81 objects
# first track box: [ 102.98066176  734.32630316  121.25301739 1075.90517302]
# 257
# MOT tracker tracks 78 objects
# first track box: [  99.0008353   732.94148791  124.35232971 1078.57046571]
# 258
# MOT tracker tracks 78 objects
# first track box: [  99.70727537  736.14793     123.82069307 1075.70423525]
# 259
# MOT tracker tracks 79 objects
# first track box: [ 102.71994876  731.09800418  122.14906788 1084.80196596]
# 260
# MOT tracker tracks 85 objects
# first track box: [ 103.83288972  746.45426735  121.9528217  1062.87015265]
# 261
# MOT tracker tracks 83 objects
# first track box: [ 103.93399118  732.28514406  122.86013568 1082.21499722]
# 262
# MOT tracker tracks 78 objects
# first track box: [ 101.77215945  731.58578368  124.43028061 1085.24421607]
# 263
# MOT tracker tracks 79 objects
# first track box: [  99.60642409  746.29015766  125.32597289 1062.70222213]
# 264
# MOT tracker tracks 79 objects
# first track box: [ 101.80089952  734.82876115  123.19696508 1074.68141605]
# 265
# MOT tracker tracks 84 objects
# first track box: [ 101.4299718   735.43784229  123.37928949 1073.5933175 ]
# 266
# MOT tracker tracks 80 objects
# first track box: [  99.01261046  737.20434031  124.67267633 1068.80482934]
# 267
# MOT tracker tracks 77 objects
# first track box: [ 100.67838538  727.9517205   122.9855389  1081.90410824]
# 268
# MOT tracker tracks 75 objects
# first track box: [ 100.81639301  726.67521346  122.8421694  1087.9998561 ]
# 269
# MOT tracker tracks 77 objects
# first track box: [ 101.40899991  748.71379606  122.49508329 1058.44057228]
# 270
# MOT tracker tracks 79 objects
# first track box: [ 100.98238678  739.4604366   122.9056907  1066.84302348]
# 271
# MOT tracker tracks 76 objects
# first track box: [  98.87229463  728.51190758  124.53017741 1082.11032806]
# 272
# MOT tracker tracks 84 objects
# first track box: [ 102.31053969  735.06492068  121.86927066 1075.2900233 ]
# 273
# MOT tracker tracks 85 objects
# first track box: [  99.10558747  733.90868063  124.56503477 1076.67581064]
# 274
# MOT tracker tracks 85 objects
# first track box: [ 103.01691401  731.08568178  121.64291244 1082.31085733]
# 275
# MOT tracker tracks 85 objects
# first track box: [ 101.76403421  736.10660264  122.56480749 1076.13254203]
# 276
# MOT tracker tracks 82 objects
# first track box: [  99.69304304  733.24038522  124.34064302 1080.57120032]
# 277
# MOT tracker tracks 82 objects
# first track box: [ 100.89586409  733.26173563  123.11805125 1082.12165727]
# 278
# MOT tracker tracks 82 objects
# first track box: [  98.91919729  733.51591959  124.60216241 1083.42024396]
# 279
# MOT tracker tracks 80 objects
# first track box: [  98.56176526  736.82322383  124.53515962 1079.48655645]
# 280
# MOT tracker tracks 79 objects
# first track box: [ 101.25669466  738.41228095  122.67406299 1076.80362883]
# 281
# MOT tracker tracks 81 objects
# first track box: [  99.26740034  733.10902107  123.96674512 1083.96698004]
# 282
# MOT tracker tracks 84 objects
# first track box: [  99.9828188   734.96765074  123.12542818 1083.20749128]
# 283
# MOT tracker tracks 83 objects
# first track box: [ 100.57575125  738.77510291  122.67163928 1076.71835277]
# 284
# MOT tracker tracks 84 objects
# first track box: [ 104.14867265  742.15724983  120.6602409  1071.9077693 ]
# 285
# MOT tracker tracks 80 objects
# first track box: [  98.94994395  738.98847099  125.06975248 1072.63185366]
# 286
# MOT tracker tracks 80 objects
# first track box: [ 100.8452905   748.27281003  123.19102572 1053.84440935]
# 287
# MOT tracker tracks 82 objects
# first track box: [ 100.09330982  733.74141868  123.95448356 1069.02002026]
# 288
# MOT tracker tracks 80 objects
# first track box: [  99.45601404  730.48618535  124.36044349 1074.67036348]
# 289
# MOT tracker tracks 78 objects
# first track box: [ 100.70404321  723.02366946  123.86386334 1092.68935965]
# 290
# MOT tracker tracks 78 objects
# first track box: [  98.55507769  734.17803552  125.23280897 1082.16406537]
# 291
# MOT tracker tracks 77 objects
# first track box: [  98.40402902  739.72578613  124.46090438 1073.983417  ]
# 292
# MOT tracker tracks 75 objects
# first track box: [ 100.91870668  733.06566104  122.34308076 1084.49279736]
# 293
# MOT tracker tracks 74 objects
# first track box: [  99.22170125  731.34842732  123.92163394 1088.79683118]
# 294
# MOT tracker tracks 78 objects
# first track box: [ 102.50064686  729.02640404  121.97898645 1096.1409118 ]
# 295
# MOT tracker tracks 77 objects
# first track box: [ 100.75413071  736.50031948  123.4585922  1088.85265247]
# 296
# MOT tracker tracks 76 objects
# first track box: [  98.76555735  737.83537834  124.48899504 1088.94886642]
# 297
# MOT tracker tracks 77 objects
# first track box: [  99.03709328  735.72557965  124.09780433 1094.06374186]
# 298
# MOT tracker tracks 78 objects
# first track box: [  99.59445785  740.00087418  123.68347296 1087.95237522]
# 299
# MOT tracker tracks 80 objects
# first track box: [ 103.16521663  742.84745248  121.67620809 1081.68258461]
# 300
# MOT tracker tracks 78 objects
# first track box: [ 103.50094397  736.0319254   122.45990626 1088.7592864 ]
# 301
# MOT tracker tracks 78 objects
# first track box: [  99.67802253  736.99097158  125.08713712 1086.30377252]
# 302
# MOT tracker tracks 79 objects
# first track box: [ 101.7613288   734.9067414   123.13134265 1089.42947042]
# 303
# MOT tracker tracks 78 objects
# first track box: [ 103.71300635  736.244462    121.99581865 1087.54009018]
# 304
# MOT tracker tracks 77 objects
# first track box: [ 102.4585521   735.44710144  123.23052512 1088.30407019]
# 305
# MOT tracker tracks 78 objects
# first track box: [ 100.84202619  736.03424618  124.57112946 1087.1900834 ]
# 306
# MOT tracker tracks 83 objects
# first track box: [  99.43535918  737.32431251  125.24478503 1083.75699149]
# 307
# MOT tracker tracks 77 objects
# first track box: [ 101.09618438  741.23431061  123.41587222 1075.36158394]
# 308
# MOT tracker tracks 76 objects
# first track box: [ 100.01570476  736.53477626  123.8746926  1077.87409533]
# 309
# MOT tracker tracks 77 objects
# first track box: [ 100.49958298  724.72558699  123.57166943 1095.98469556]
# 310
# MOT tracker tracks 78 objects
# first track box: [ 100.9553056   730.75155383  123.04527533 1091.69642066]
# 311
# MOT tracker tracks 78 objects
# first track box: [ 101.5469008   733.42940475  122.63837129 1090.76045883]
# 312
# MOT tracker tracks 79 objects
# first track box: [ 101.09503297  738.7644117   123.01878898 1085.71531622]
# 313
# MOT tracker tracks 83 objects
# first track box: [  99.87645536  739.70355494  123.70221652 1082.11903592]
# 314
# MOT tracker tracks 78 objects
# first track box: [ 101.87649122  746.85348765  122.19754993 1066.90244011]
# 315
# MOT tracker tracks 78 objects
# first track box: [  99.93419313  733.49997209  123.62545558 1082.81863325]
# 316
# MOT tracker tracks 78 objects
# first track box: [ 102.69666186  731.26610453  122.09035362 1087.62148491]
# 317
# MOT tracker tracks 79 objects
# first track box: [ 101.44221451  737.29493522  123.22349255 1079.58356207]
# 318
# MOT tracker tracks 79 objects
# first track box: [ 100.94626625  728.45517362  123.84399084 1093.38138983]
# 319
# MOT tracker tracks 83 objects
# first track box: [  98.97981268  739.29552859  124.71946905 1081.38734206]
# 320
# MOT tracker tracks 80 objects
# first track box: [ 101.61045996  740.61649339  122.09213316 1077.1277197 ]
# 321
# MOT tracker tracks 82 objects
# first track box: [ 100.92109169  738.65762545  122.79367338 1076.53268724]
# 322
# MOT tracker tracks 92 objects
# first track box: [  98.8013069   730.83607637  124.45493306 1086.2311074 ]
# 323
# MOT tracker tracks 93 objects
# first track box: [ 101.09568088  729.48887272  122.48621419 1090.93458229]
# 324
# MOT tracker tracks 88 objects
# first track box: [  98.53504662  748.17882845  124.14821918 1061.58008377]
# 325
# MOT tracker tracks 87 objects
# first track box: [  99.94261939  730.80250597  123.1619174  1081.39545051]
# 326
# MOT tracker tracks 86 objects
# first track box: [  97.92500407  735.54397086  124.60772674 1074.60077349]
# 327
# MOT tracker tracks 88 objects
# first track box: [  98.45318268  730.09738413  123.59439713 1081.92726799]
# 328
# MOT tracker tracks 84 objects
# first track box: [  99.47075746  736.08176032  122.65044864 1074.32628739]
# 329
# MOT tracker tracks 84 objects
# first track box: [  98.77952646  745.12800312  122.71068597 1057.49828996]
# 330
# MOT tracker tracks 84 objects
# first track box: [ 100.45400529  734.75312498  121.69998883 1066.93795476]
# 331
# MOT tracker tracks 81 objects
# first track box: [ 100.86557658  725.27192593  121.88621957 1082.93767081]
# 332
# MOT tracker tracks 82 objects
# first track box: [ 100.22303328  725.70988992  123.05692521 1087.3461583 ]
# 333
# MOT tracker tracks 80 objects
# first track box: [ 103.0239332   739.75915624  121.42959446 1069.6658394 ]
# 334
# MOT tracker tracks 79 objects
# first track box: [ 101.40489434  746.62079775  123.10325665 1054.62705179]
# 335
# MOT tracker tracks 80 objects
# first track box: [ 100.70198284  739.03535619  123.59274913 1058.02883843]
# 336
# MOT tracker tracks 74 objects
# first track box: [  99.05630476  721.58940441  124.79537719 1082.72852746]
# 337
# MOT tracker tracks 75 objects
# first track box: [  99.07683913  745.34517154  124.13886225 1052.30813957]
# 338
# MOT tracker tracks 78 objects
# first track box: [ 100.79758951  734.12169943  123.05455515 1064.02058628]
# 339
# MOT tracker tracks 77 objects
# first track box: [  99.22202413  739.40023889  123.99182809 1053.81839714]
# 340
# MOT tracker tracks 75 objects
# first track box: [ 102.87876043  729.74603956  121.44688385 1065.76704628]
# 341
# MOT tracker tracks 74 objects
# first track box: [ 101.65146723  746.95488857  122.44738362 1038.06874209]
# 342
# MOT tracker tracks 72 objects
# first track box: [ 101.11503438  737.92158161  123.01398742 1042.67233297]
# 343
# MOT tracker tracks 70 objects
# first track box: [ 101.07814478  727.3249195   123.06966489 1056.12207686]
# 344
# MOT tracker tracks 71 objects
# first track box: [ 100.50171361  719.89510508  123.41708176 1071.78007706]
# 345
# MOT tracker tracks 71 objects
# first track box: [ 101.51545209  723.93867448  122.6761902  1074.09686173]
# 346
# MOT tracker tracks 71 objects
# first track box: [  99.05808831  731.90879643  124.6519764  1070.01303436]
# 347
# MOT tracker tracks 73 objects
# first track box: [ 101.64773755  750.19702804  122.11717785 1042.40178655]
# 348
# MOT tracker tracks 73 objects
# first track box: [ 101.54868014  744.11740083  122.50415546 1044.37930226]
# 349
# MOT tracker tracks 72 objects
# first track box: [  95.88025325  727.08673577  126.03731456 1066.50014527]
# 350
# MOT tracker tracks 72 objects
# first track box: [  94.56894445  739.11510519  125.49820485 1051.5834849 ]
# 351
# MOT tracker tracks 69 objects
# first track box: [  98.60675027  732.56813802  122.27217552 1060.18080086]
# 352
# MOT tracker tracks 68 objects
# first track box: [  99.52600141  740.23806721  122.58184404 1051.71612569]
# 353
# MOT tracker tracks 69 objects
# first track box: [ 100.77640229  726.21385142  121.94892905 1073.89716152]
# 354
# MOT tracker tracks 68 objects
# first track box: [ 101.60448056  731.58629482  122.61895904 1071.31500008]
# 355
# MOT tracker tracks 68 objects
# first track box: [  99.13395911  728.43875001  124.71557306 1079.4089403 ]
# 356
# MOT tracker tracks 69 objects
# first track box: [  99.10873128  744.95371138  124.15754045 1056.55977907]
# 357
# MOT tracker tracks 70 objects
# first track box: [  97.95617026  727.11749207  124.7924259  1083.05626278]
# 358
# MOT tracker tracks 69 objects
# first track box: [  99.14908253  746.89078126  123.38710172 1056.16557394]
# 359
# MOT tracker tracks 70 objects
# first track box: [  96.62079905  744.86792454  124.3050928  1051.14274585]
# 360
# MOT tracker tracks 72 objects
# first track box: [  98.56943306  735.66120684  122.87861979 1061.83802513]
# 361
# MOT tracker tracks 71 objects
# first track box: [  99.86734249  741.99734708  122.06112995 1049.69059004]
# 362
# MOT tracker tracks 71 objects
# first track box: [  95.55421016  732.99655066  124.89911111 1062.04064256]
# 363
# MOT tracker tracks 71 objects
# first track box: [  94.62025124  729.69954703  124.56527518 1067.86404506]
# 364
# MOT tracker tracks 69 objects
# first track box: [ 100.98831625  730.90889687  119.99074525 1069.83878137]
# 365
# MOT tracker tracks 71 objects
# first track box: [  99.2574806   757.18668918  122.83808336 1027.47482134]
# 366
# MOT tracker tracks 72 objects
# first track box: [ 102.54058499  729.98879025  121.00891038 1059.55815627]
# 367
# MOT tracker tracks 73 objects
# first track box: [ 101.6489627   724.5275556   122.43650401 1073.72909215]
# 368
# MOT tracker tracks 73 objects
# first track box: [ 100.85447047  729.27480917  123.66880046 1072.79524347]
# 369
# MOT tracker tracks 75 objects
# first track box: [ 100.36654714  728.70874845  124.26704546 1080.91322124]
# 370
# MOT tracker tracks 77 objects
# first track box: [ 103.57798401  730.17337816  122.07315511 1084.93877691]
# 371
# MOT tracker tracks 78 objects
# first track box: [ 101.92111017  741.39585528  123.62698417 1072.55809313]
# 372
# MOT tracker tracks 74 objects
# first track box: [ 101.96056364  731.46595463  123.93588052 1087.21372381]
# 373
# MOT tracker tracks 73 objects
# first track box: [ 102.42234541  734.65601197  123.50419421 1086.97052557]
# 374
# MOT tracker tracks 73 objects
# first track box: [ 101.8789593   730.97914885  123.80190785 1095.83065986]
# 375
# MOT tracker tracks 76 objects
# first track box: [ 103.69329027  737.31855201  122.93858475 1090.3970536 ]
# 376
# MOT tracker tracks 81 objects
# first track box: [ 101.65841715  736.37080046  124.34332144 1093.04170746]
# 377
# MOT tracker tracks 82 objects
# first track box: [ 104.11198407  744.61888092  122.50514225 1080.52142835]
# 378
# MOT tracker tracks 81 objects
# first track box: [ 103.8712484   742.54243677  123.73640189 1081.28249788]
# 379
# MOT tracker tracks 80 objects
# first track box: [ 102.59377363  736.32092371  124.41461684 1088.12422655]
# 380
# MOT tracker tracks 78 objects
# first track box: [ 100.74136103  735.30792648  125.47456551 1090.03965896]
# 381
# MOT tracker tracks 76 objects
# first track box: [ 101.75864314  742.97610807  123.98801426 1077.79983977]
# 382
# MOT tracker tracks 77 objects
# first track box: [  99.58601345  738.39467793  125.26958146 1080.70852372]
# 383
# MOT tracker tracks 80 objects
# first track box: [ 101.12616819  748.18537752  123.43529401 1061.81324225]
# 384
# MOT tracker tracks 80 objects
# first track box: [  99.99205906  746.46843894  123.85016053 1054.94073057]
# 385
# MOT tracker tracks 81 objects
# first track box: [  99.04603028  725.85723954  123.95020191 1079.70086351]
# 386
# MOT tracker tracks 82 objects
# first track box: [  99.8022548   743.95824723  122.96205329 1053.97329453]
# 387
# MOT tracker tracks 82 objects
# first track box: [  98.63636617  732.60738369  123.48193606 1064.59456126]
# 388
# MOT tracker tracks 81 objects
# first track box: [  97.04667126  724.81019167  124.7819508  1076.04679106]
# 389
# MOT tracker tracks 80 objects
# first track box: [ 100.38197318  741.98779429  121.9471993  1052.7001393 ]
# 390
# MOT tracker tracks 79 objects
# first track box: [ 101.79085964  741.86269014  121.00613397 1046.42599159]
# 391
# MOT tracker tracks 79 objects
# first track box: [ 100.60994116  721.15845521  122.37624637 1074.67403588]
# 392
# MOT tracker tracks 78 objects
# first track box: [ 102.90058998  731.64551337  121.21665913 1064.53502578]
# 393
# MOT tracker tracks 78 objects
# first track box: [ 101.46831058  723.91347516  123.1591543  1078.89011781]
# 394
# MOT tracker tracks 78 objects
# first track box: [ 102.45931118  728.84965678  122.60120715 1078.35121793]
# 395
# MOT tracker tracks 80 objects
# first track box: [ 103.85903172  745.98395015  122.0387801  1053.80245103]
# 396
# MOT tracker tracks 80 objects
# first track box: [ 104.53278386  727.45250883  122.54786839 1078.49302719]
# 397
# MOT tracker tracks 79 objects
# first track box: [ 100.4189918   728.52602186  125.74889596 1081.36158174]
# 398
# MOT tracker tracks 77 objects
# first track box: [ 102.34490285  748.02486369  123.70826935 1055.20707468]
# 399
# MOT tracker tracks 78 objects
# first track box: [ 102.45057575  747.01327563  123.48106954 1050.36424768]
# 400
# MOT tracker tracks 76 objects
# first track box: [ 102.403158    744.64687689  123.40571705 1047.67633054]
# 401
# MOT tracker tracks 74 objects
# first track box: [ 102.3444635   742.51984028  123.34467826 1045.52231204]
# 402
# MOT tracker tracks 74 objects
# first track box: [ 102.28779409  740.74431128  123.28781211 1043.74451871]
# 403
# MOT tracker tracks 72 objects
# first track box: [ 102.2352363   739.30247041  123.23523781 1042.30248782]
# 404
# MOT tracker tracks 72 objects
# first track box: [ 102.18757616  738.1622162   123.18757629 1041.16221767]
# 405
# MOT tracker tracks 70 objects
# first track box: [ 102.1451971   737.28867158  123.14519711 1040.2886717 ]
# 406
# MOT tracker tracks 70 objects
# first track box: [ 102.10821502  736.64656991  123.10821502 1039.64656992]
# 407
# MOT tracker tracks 63 objects
# first track box: [ 102.07654266  736.201542    123.07654266 1039.201542  ]
# 408
# MOT tracker tracks 61 objects
# first track box: [ 102.04994125  735.92102144  123.04994125 1038.92102144]
# 409
# MOT tracker tracks 55 objects
# first track box: [ 102.0280644   735.77487163  123.0280644  1038.77487163]
# 410
# MOT tracker tracks 54 objects
# first track box: [ 102.01049508  735.7357842   123.01049508 1038.7357842 ]
# 411
# MOT tracker tracks 54 objects
# first track box: [ 101.99677592  735.77949045  122.99677592 1038.77949045]
# 412
# MOT tracker tracks 53 objects
# first track box: [ 101.98643374  735.88482387  122.98643374 1038.88482387]
# 413
# MOT tracker tracks 52 objects
# first track box: [ 101.97899862  736.03366693  122.97899862 1039.03366693]
# 414
# MOT tracker tracks 52 objects
# first track box: [ 101.97401843  736.2108118   122.97401843 1039.2108118 ]
# 415
# MOT tracker tracks 52 objects
# first track box: [ 101.9710692  736.4037597  122.9710692 1039.4037597]
# 416
# MOT tracker tracks 52 objects
# first track box: [ 101.96976219  736.60248037  122.96976219 1039.60248037]
# 417
# MOT tracker tracks 52 objects
# first track box: [ 101.96974811  736.79914866  122.96974811 1039.79914866]
# 418
# MOT tracker tracks 52 objects
# first track box: [ 101.97071901  736.98787254  122.97071901 1039.98787254]
# 419
# MOT tracker tracks 52 objects
# first track box: [ 101.97240845  737.16442313  122.97240845 1040.16442313]
# 420
# MOT tracker tracks 52 objects
# first track box: [ 101.97459023  737.32597527  122.97459023 1040.32597527]
# 421
# MOT tracker tracks 52 objects
# first track box: [ 101.9770761   737.47086433  122.9770761  1040.47086433]
# 422
# MOT tracker tracks 52 objects
# first track box: [ 101.97971288  737.59836344  122.97971288 1040.59836344]
# 423
# MOT tracker tracks 52 objects
# first track box: [ 101.98237901  737.70848337  122.98237901 1040.70848337]
# 424
# MOT tracker tracks 52 objects
# first track box: [ 101.98498098  737.80179627  122.98498098 1040.80179627]
# 425
# MOT tracker tracks 52 objects
# first track box: [ 101.98744965  737.87928315  122.98744965 1040.87928315]
# 426
# MOT tracker tracks 52 objects
# first track box: [ 101.98973673  737.94220459  122.98973673 1040.94220459]
# 427
# MOT tracker tracks 52 objects
# first track box: [ 101.99181131  737.99199308  122.99181131 1040.99199308]
# 428
# MOT tracker tracks 52 objects
# first track box: [ 101.99365676  738.03016561  122.99365676 1041.03016561]
# 429
# MOT tracker tracks 52 objects
# first track box: [ 101.99526786  738.05825423  122.99526786 1041.05825423]
# 430
# MOT tracker tracks 52 objects
# first track box: [ 101.99664822  738.07775275  122.99664822 1041.07775275]
# 431
# MOT tracker tracks 52 objects
# first track box: [ 101.99780809  738.09007744  122.99780809 1041.09007744]
# 432
# MOT tracker tracks 52 objects
# first track box: [ 101.99876243  738.09653951  122.99876243 1041.09653951]
# 433
# MOT tracker tracks 52 objects
# first track box: [ 101.99952929  738.09832766  122.99952929 1041.09832766]
# 434
# MOT tracker tracks 52 objects
# first track box: [ 102.00012851  738.09649871  123.00012851 1041.09649871]
# 435
# MOT tracker tracks 52 objects
# first track box: [ 102.00058063  738.09197477  123.00058063 1041.09197477]
# 436
# MOT tracker tracks 52 objects
# first track box: [ 102.00090607  738.08554546  123.00090607 1041.08554546]
# 437
# MOT tracker tracks 52 objects
# first track box: [ 102.00112448  738.07787387  123.00112448 1041.07787387]
# 438
# MOT tracker tracks 52 objects
# first track box: [ 102.00125431  738.06950526  123.00125431 1041.06950526]
# 439
# MOT tracker tracks 52 objects
# first track box: [ 102.00131247  738.06087743  123.00131247 1041.06087743]
# 440
# MOT tracker tracks 52 objects
# first track box: [ 102.00131417  738.05233217  123.00131417 1041.05233217]
# 441
# MOT tracker tracks 52 objects
# first track box: [ 102.00127282  738.04412706  123.00127282 1041.04412706]
# 442
# MOT tracker tracks 52 objects
# first track box: [ 102.00120004  738.03644722  123.00120004 1041.03644722]
# 443
# MOT tracker tracks 52 objects
# first track box: [ 102.00110567  738.02941655  123.00110567 1041.02941655]
# 444
# MOT tracker tracks 52 objects
# first track box: [ 102.00099794  738.02310835  123.00099794 1041.02310835]
# 445
# MOT tracker tracks 52 objects
# first track box: [ 102.00088352  738.01755497  123.00088352 1041.01755497]
# 446
# MOT tracker tracks 52 objects
# first track box: [ 102.00076772  738.01275658  123.00076772 1041.01275658]
# 447
# MOT tracker tracks 52 objects
# first track box: [ 102.00065464  738.0086888   123.00065464 1041.0086888 ]
# 448
# MOT tracker tracks 52 objects
# first track box: [ 102.00054728  738.00530934  123.00054728 1041.00530934]
# 449
# MOT tracker tracks 52 objects
# first track box: [ 102.00044778  738.00256368  123.00044778 1041.00256368]
# 450
# MOT tracker tracks 52 objects
# first track box: [ 102.00035747  738.00038975  123.00035747 1041.00038975]
# 451
# MOT tracker tracks 52 objects
# first track box: [ 102.00027711  737.9987217   123.00027711 1040.9987217 ]
# 452
# MOT tracker tracks 52 objects
# first track box: [ 102.00020693  737.99749301  123.00020693 1040.99749301]
# 453
# MOT tracker tracks 52 objects
# first track box: [ 102.00014677  737.99663873  123.00014677 1040.99663873]
# 454
# MOT tracker tracks 52 objects
# first track box: [ 102.0000962   737.99609729  123.0000962  1040.99609729]
# 455
# MOT tracker tracks 52 objects
# first track box: [ 102.00005457  737.99581163  123.00005457 1040.99581163]
# 456
# MOT tracker tracks 52 objects
# first track box: [ 102.00002109  737.99573002  123.00002109 1040.99573002]
# 457
# MOT tracker tracks 52 objects
# first track box: [ 101.99999492  737.99580643  122.99999492 1040.99580643]
# 458
# MOT tracker tracks 52 objects
# first track box: [ 101.99997516  737.99600068  122.99997516 1040.99600068]
# 459
# MOT tracker tracks 52 objects
# first track box: [ 101.99996091  737.99627838  122.99996091 1040.99627838]
# 460
# MOT tracker tracks 52 objects
# first track box: [ 101.99995133  737.9966106   122.99995133 1040.9966106 ]
# 461
# MOT tracker tracks 52 objects
# first track box: [ 101.99994562  737.99697355  122.99994562 1040.99697355]
# 462
# MOT tracker tracks 52 objects
# first track box: [ 101.99994303  737.99734814  122.99994303 1040.99734814]
# 463
# MOT tracker tracks 52 objects
# first track box: [ 101.99994291  737.99771943  122.99994291 1040.99771943]
# 464
# MOT tracker tracks 52 objects
# first track box: [ 101.99994467  737.99807615  122.99994467 1040.99807615]
# 465
# MOT tracker tracks 52 objects
# first track box: [ 101.99994781  737.99841022  122.99994781 1040.99841022]
# 466
# MOT tracker tracks 52 objects
# first track box: [ 101.99995189  737.99871619  122.99995189 1040.99871619]
# 467
# MOT tracker tracks 52 objects
# first track box: [ 101.99995656  737.99899083  122.99995656 1040.99899083]
# 468
# MOT tracker tracks 52 objects
# first track box: [ 101.99996152  737.99923271  122.99996152 1040.99923271]
# 469
# MOT tracker tracks 52 objects
# first track box: [ 101.99996655  737.9994418   122.99996655 1040.9994418 ]
# 470
# MOT tracker tracks 52 objects
# first track box: [ 101.99997147  737.99961912  122.99997147 1040.99961912]
# 471
# MOT tracker tracks 52 objects
# first track box: [ 101.99997613  737.99976651  122.99997613 1040.99976651]
# 472
# MOT tracker tracks 52 objects
# first track box: [ 101.99998046  737.99988632  122.99998046 1040.99988632]
# 473
# MOT tracker tracks 52 objects
# first track box: [ 101.99998439  737.99998124  122.99998439 1040.99998124]
# 474
# MOT tracker tracks 52 objects
# first track box: [ 101.99998789  738.00005413  122.99998789 1041.00005413]
# 475
# MOT tracker tracks 52 objects
# first track box: [ 101.99999095  738.00010787  122.99999095 1041.00010787]
# 476
# MOT tracker tracks 52 objects
# first track box: [ 101.99999357  738.0001453   122.99999357 1041.0001453 ]
# 477
# MOT tracker tracks 52 objects
# first track box: [ 101.99999578  738.00016908  122.99999578 1041.00016908]
# 478
# MOT tracker tracks 52 objects
# first track box: [ 101.99999759  738.00018171  122.99999759 1041.00018171]
# 479
# MOT tracker tracks 52 objects
# first track box: [ 101.99999906  738.00018542  122.99999906 1041.00018542]
# 480
# MOT tracker tracks 52 objects
# first track box: [ 102.0000002   738.00018224  123.0000002  1041.00018224]
# 481
# MOT tracker tracks 52 objects
# first track box: [ 102.00000106  738.0001739   123.00000106 1041.0001739 ]
# 482
# MOT tracker tracks 52 objects
# first track box: [ 102.00000169  738.00016191  123.00000169 1041.00016191]
# 483
# MOT tracker tracks 52 objects
# first track box: [ 102.00000211  738.00014752  123.00000211 1041.00014752]
# 484
# MOT tracker tracks 52 objects
# first track box: [ 102.00000236  738.00013178  123.00000236 1041.00013178]
# 485
# MOT tracker tracks 52 objects
# first track box: [ 102.00000247  738.00011552  123.00000247 1041.00011552]
# 486
# MOT tracker tracks 52 objects
# first track box: [ 102.00000248  738.00009938  123.00000248 1041.00009938]
# 487
# MOT tracker tracks 52 objects
# first track box: [ 102.00000241  738.00008387  123.00000241 1041.00008387]
# 488
# MOT tracker tracks 52 objects
# first track box: [ 102.00000227  738.00006934  123.00000227 1041.00006934]
# 489
# MOT tracker tracks 52 objects
# first track box: [ 102.00000209  738.00005603  123.00000209 1041.00005603]
# 490
# MOT tracker tracks 52 objects
# first track box: [ 102.00000189  738.00004407  123.00000189 1041.00004407]
# 491
# MOT tracker tracks 52 objects
# first track box: [ 102.00000168  738.00003354  123.00000168 1041.00003354]
# 492
# MOT tracker tracks 52 objects
# first track box: [ 102.00000146  738.00002443  123.00000146 1041.00002443]
# 493
# MOT tracker tracks 52 objects
# first track box: [ 102.00000124  738.0000167   123.00000124 1041.0000167 ]
# 494
# MOT tracker tracks 52 objects
# first track box: [ 102.00000104  738.00001027  123.00000104 1041.00001027]
# 495
# MOT tracker tracks 52 objects
# first track box: [ 102.00000085  738.00000504  123.00000085 1041.00000504]
# 496
# MOT tracker tracks 52 objects
# first track box: [ 102.00000068  738.00000089  123.00000068 1041.00000089]
# 497
# MOT tracker tracks 52 objects
# first track box: [ 102.00000053  737.99999771  123.00000053 1040.99999771]
# 498
# MOT tracker tracks 52 objects
# first track box: [ 102.0000004   737.99999536  123.0000004  1040.99999536]
# 499
# MOT tracker tracks 52 objects
# first track box: [ 102.00000028  737.99999372  123.00000028 1040.99999372]
# 500
# MOT tracker tracks 52 objects
# first track box: [ 102.00000019  737.99999267  123.00000019 1040.99999267]
# 501
# MOT tracker tracks 52 objects
# first track box: [ 102.00000011  737.99999212  123.00000011 1040.99999212]
# 502
# MOT tracker tracks 52 objects
# first track box: [ 102.00000004  737.99999195  123.00000004 1040.99999195]
# 503
# MOT tracker tracks 52 objects
# first track box: [ 101.99999999  737.99999208  122.99999999 1040.99999208]
# 504
# MOT tracker tracks 52 objects
# first track box: [ 101.99999995  737.99999244  122.99999995 1040.99999244]
# 505
# MOT tracker tracks 52 objects
# first track box: [ 101.99999993  737.99999296  122.99999993 1040.99999296]
# 506
# MOT tracker tracks 52 objects
# first track box: [ 101.99999991  737.99999358  122.99999991 1040.99999358]
# 507
# MOT tracker tracks 52 objects
# first track box: [ 101.9999999   737.99999426  122.9999999  1040.99999426]
# 508
# MOT tracker tracks 52 objects
# first track box: [ 101.99999989  737.99999497  122.99999989 1040.99999497]
# 509
# MOT tracker tracks 52 objects
# first track box: [ 101.99999989  737.99999567  122.99999989 1040.99999567]
# 510
# MOT tracker tracks 52 objects
# first track box: [ 101.9999999   737.99999634  122.9999999  1040.99999634]
# 511
# MOT tracker tracks 52 objects
# first track box: [ 101.9999999   737.99999698  122.9999999  1040.99999698]
# 512
# MOT tracker tracks 52 objects
# first track box: [ 101.99999991  737.99999755  122.99999991 1040.99999755]
# 513
# MOT tracker tracks 52 objects
# first track box: [ 101.99999992  737.99999808  122.99999992 1040.99999808]
# 514
# MOT tracker tracks 52 objects
# first track box: [ 101.99999993  737.99999853  122.99999993 1040.99999853]
# 515
# MOT tracker tracks 52 objects
# first track box: [ 101.99999994  737.99999893  122.99999994 1040.99999893]
# 516
# MOT tracker tracks 52 objects
# first track box: [ 101.99999995  737.99999927  122.99999995 1040.99999927]
# 517
# MOT tracker tracks 52 objects
# first track box: [ 101.99999995  737.99999955  122.99999995 1040.99999955]
# 518
# MOT tracker tracks 52 objects
# first track box: [ 101.99999996  737.99999978  122.99999996 1040.99999978]
# 519
# MOT tracker tracks 52 objects
# first track box: [ 101.99999997  737.99999996  122.99999997 1040.99999996]
# 520
# MOT tracker tracks 52 objects
# first track box: [ 101.99999998  738.0000001   122.99999998 1041.0000001 ]
# 521
# MOT tracker tracks 52 objects
# first track box: [ 101.99999998  738.0000002   122.99999998 1041.0000002 ]
# 522
# MOT tracker tracks 52 objects
# first track box: [ 101.99999999  738.00000027  122.99999999 1041.00000027]
# 523
# MOT tracker tracks 52 objects
# first track box: [ 101.99999999  738.00000032  122.99999999 1041.00000032]
# 524
# MOT tracker tracks 52 objects
# first track box: [ 102.          738.00000034  123.         1041.00000034]
# 525
# MOT tracker tracks 52 objects
# first track box: [ 102.          738.00000035  123.         1041.00000035]
# 526
# MOT tracker tracks 52 objects
# first track box: [ 102.          738.00000034  123.         1041.00000034]
# 527
# MOT tracker tracks 52 objects
# first track box: [ 102.          738.00000033  123.         1041.00000033]
# 528
# MOT tracker tracks 52 objects
# first track box: [ 102.          738.00000031  123.         1041.00000031]
# 529
# MOT tracker tracks 52 objects
# first track box: [ 102.          738.00000028  123.         1041.00000028]
# 530
# MOT tracker tracks 52 objects
# first track box: [ 102.          738.00000025  123.         1041.00000025]
# 531
# MOT tracker tracks 52 objects
# first track box: [ 102.          738.00000022  123.         1041.00000022]
# 532
# MOT tracker tracks 52 objects
# first track box: [ 102.          738.00000019  123.         1041.00000019]
# 533
# MOT tracker tracks 52 objects
# first track box: [ 102.          738.00000016  123.         1041.00000016]
# 534
# MOT tracker tracks 52 objects
# first track box: [ 102.          738.00000013  123.         1041.00000013]
# 535
# MOT tracker tracks 52 objects
# first track box: [ 102.          738.00000011  123.         1041.00000011]
# 536
# MOT tracker tracks 52 objects
# first track box: [ 102.          738.00000008  123.         1041.00000008]
# 537
# MOT tracker tracks 52 objects
# first track box: [ 102.          738.00000006  123.         1041.00000006]
# 538
# MOT tracker tracks 52 objects
# first track box: [ 102.          738.00000005  123.         1041.00000005]
# 539
# MOT tracker tracks 52 objects
# first track box: [ 102.          738.00000003  123.         1041.00000003]
# 540
# MOT tracker tracks 52 objects
# first track box: [ 102.          738.00000002  123.         1041.00000002]
# 541
# MOT tracker tracks 52 objects
# first track box: [ 102.          738.00000001  123.         1041.00000001]
# 542
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 543
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 544
# MOT tracker tracks 52 objects
# first track box: [ 102.          737.99999999  123.         1040.99999999]
# 545
# MOT tracker tracks 52 objects
# first track box: [ 102.          737.99999999  123.         1040.99999999]
# 546
# MOT tracker tracks 52 objects
# first track box: [ 102.          737.99999999  123.         1040.99999999]
# 547
# MOT tracker tracks 52 objects
# first track box: [ 102.          737.99999999  123.         1040.99999999]
# 548
# MOT tracker tracks 52 objects
# first track box: [ 102.          737.99999998  123.         1040.99999998]
# 549
# MOT tracker tracks 52 objects
# first track box: [ 102.          737.99999999  123.         1040.99999999]
# 550
# MOT tracker tracks 52 objects
# first track box: [ 102.          737.99999999  123.         1040.99999999]
# 551
# MOT tracker tracks 52 objects
# first track box: [ 102.          737.99999999  123.         1040.99999999]
# 552
# MOT tracker tracks 52 objects
# first track box: [ 102.          737.99999999  123.         1040.99999999]
# 553
# MOT tracker tracks 52 objects
# first track box: [ 102.          737.99999999  123.         1040.99999999]
# 554
# MOT tracker tracks 52 objects
# first track box: [ 102.          737.99999999  123.         1040.99999999]
# 555
# MOT tracker tracks 52 objects
# first track box: [ 102.          737.99999999  123.         1040.99999999]
# 556
# MOT tracker tracks 52 objects
# first track box: [ 102.          737.99999999  123.         1040.99999999]
# 557
# MOT tracker tracks 52 objects
# first track box: [ 102.          737.99999999  123.         1040.99999999]
# 558
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 559
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 560
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 561
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 562
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 563
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 564
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 565
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 566
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 567
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 568
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 569
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 570
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 571
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 572
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 573
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 574
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 575
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 576
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 577
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 578
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 579
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 580
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 581
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 582
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 583
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 584
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 585
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 586
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 587
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 588
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 589
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 590
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 591
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 592
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 593
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 594
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 595
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 596
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 597
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 598
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]
# 599
# MOT tracker tracks 52 objects
# first track box: [ 102.  738.  123. 1041.]

# %%
track
# Out:
# Track(id='898b96ee-185c-4bc8-89ae-65ea1549a08b', box=array([429., 654., 437., 677.]), score=None, class_id=None)

# %%
for track in tracks:
    print(track.id)
    print(track.box)
# Out:
# a0fa9fdd-8ba2-4e79-92db-3389431c31a2
# [ 102.  738.  123. 1041.]
# 61429404-f2b6-4cca-bce6-7262a398dffb
# [-175.  555. -100.  585.]
# 30a09afc-0304-4cfe-9d10-e9b4c6231fb9
# [-349.  242. -306.  290.]
# d20da6a6-20a3-4b53-91c0-e651122c21b7
# [-200.  211.  -24.  372.]
# 6b069009-8127-4c4a-bf19-4f0f8af3eb0e
# [ 19. 560.  79. 587.]
# 00e1212e-ff90-4ea5-bcc6-804c5f6a1542
# [ 45. 440. 137. 479.]
# 508914cc-af1f-4216-a847-65d8520c18ca
# [128. 507. 229. 543.]
# b627fcf9-791d-4ff8-be40-08a3988ee983
# [ 85. 593.  91. 621.]
# 1af5c4f4-ac32-4d86-b3b1-17ec29dd6d7c
# [ 34. 192. 221. 310.]
# 18ecb6e7-9bbf-4e7b-96f2-7c497d8a6a90
# [202. 626. 229. 659.]
# 366f0ba5-5ca8-4c61-b602-c4cf3c98df79
# [ 606. 1015.  655. 1081.]
# 9175ac2a-9f5e-48e8-be7b-1dbeef184c26
# [ 198. 1015.  228. 1097.]
# 81d345b6-7cbd-47ad-aa78-46c5d116cdbc
# [-299.  560. -241.  590.]
# 88273578-5b46-4568-a739-50cc7e5eeae8
# [-200.  598. -192.  636.]
# f6f0d725-61b6-428d-8239-5ff6072d8d17
# [-191.  300. -166.  336.]
# 3e85b1e7-4c37-4fd6-902a-40b3bf795ad9
# [ 523. -217.  637.   18.]
# be817d84-1d3e-4051-b7b4-06dbee9f4b9d
# [807. 356. 866. 421.]
# 948c45ff-79a2-4cf6-acd5-d7b19ce181f5
# [ 624. 1443.  644. 1480.]
# 54e617e1-b541-4de5-9804-eadbf464cd69
# [ 738.  959.  781. 1004.]
# a492dde1-79ab-4b89-a63a-09f08479a1a1
# [735. 627. 752. 677.]
# d9db5e58-1515-49a5-8eb7-ecd5ff6591d2
# [721. 725. 763. 769.]
# e4c1a2dd-9a0f-4391-b960-1a14f211461d
# [884. 256. 910. 291.]
# 74d7f6a4-5437-43b2-b5c1-38894806c714
# [723. 251. 744. 274.]
# 10556c65-38ec-4421-90e3-213a33b8b6e0
# [ 365. 1489.  389. 1506.]
# 4bc0f41d-3243-453d-b5e2-4dabc367a7ab
# [ 727. 1012.  761. 1046.]
# 32817618-bfb3-4e7f-9f45-42401c1d17f7
# [720. 767. 763. 948.]
# 46d8ad2b-b4a6-4b15-8671-80aa4c5f2521
# [ 631. 1169.  638. 1203.]
# 447c671a-b1e5-4917-ada7-06d69bf82690
# [615.  36. 635. 128.]
# 155560fa-a748-484b-ab10-ad39ed615490
# [128.  75. 230. 189.]
# 323efc0e-a54b-4095-9609-9e78e9243435
# [ 133. -280.  187. -222.]
# 6571254b-4317-40c1-bc60-3d5d408e8252
# [188. -15. 198.  46.]
# 37cfa25b-6018-4506-ab13-a33034abe1bb
# [-294.  195. -229.  281.]
# f82c372f-fb72-45fe-8f0f-76917bf0c7d5
# [-126.  184. -102.  210.]
# e42e69a5-ec37-48b3-a3ca-71c49587de63
# [626. 801. 646. 835.]
# 941597fc-635c-47ff-8b21-2951ef8aa45c
# [612. 193. 632. 224.]
# 9596063a-6b0d-41e8-b221-103077216337
# [501. 246. 512. 260.]
# ad450a15-f464-496d-8b68-eaec1f5f2af7
# [329.  17. 354.  50.]
# 1d71865e-7c05-4e2b-a0c9-b24d6d190801
# [ 356. 1335.  394. 1355.]
# 70a38830-b8c3-4333-8d97-0fee7b01df4d
# [-386.  600. -300.  695.]
# aa7001bc-dc68-4b24-8258-21095ce47f2b
# [-280.  323. -247.  354.]
# 2c885786-2831-45f9-900e-251fd34d494b
# [622. 662. 629. 679.]
# 60b5b68a-3d80-4177-8336-41e529f97986
# [468. 173. 484. 193.]
# dd50bfed-87e1-49b1-bfcb-17581f2f98af
# [-410.  569. -337.  619.]
# 202a2600-d02b-4355-b7a3-a8439bc353f6
# [372. 217. 386. 231.]
# 83931d82-6413-42dc-8c23-97495142c51f
# [ 207. 1529.  219. 1543.]
# 0e48b732-4b0f-4f1c-8dd8-5142e9a2f23e
# [669. -90. 682. -20.]
# 752c207e-18fd-4278-820a-0f6c8240f0e9
# [ 19. 216.  46. 248.]
# ad4de96f-50ac-4735-9a01-1944a08376aa
# [ 628. 1094.  647. 1117.]
# 6bfea887-597c-4f7a-810f-b17a7d6471ce
# [-726.  677. -718.  694.]
# 508bd841-81c9-431e-9a3e-1762e8c5ddcd
# [ 35. 658.  41. 669.]
# 6ba86cce-124c-4116-b767-e8691383fe4c
# [363. 664. 370. 680.]
# 898b96ee-185c-4bc8-89ae-65ea1549a08b
# [429. 654. 437. 677.]

# %%
clustered_point_cloud[idx][i][0]
# Out:
# (721, 725)

# %%
np.array(clustered_point_cloud[idx][i][0]+clustered_point_cloud[idx][i][1])
# Out:
# array([721, 725, 763, 769])

# %%
# writing on the video
from motpy import Detection, MultiObjectTracker
cap = cv2.VideoCapture('output1640b_transformed.mp4')
out = cv2.VideoWriter('synchronization_filtered_demo.mp4', cv2.VideoWriter_fourcc(*'mp4v'), 15, (832, 832))

counter = 0
from motpy import Detection, MultiObjectTracker
tracker = MultiObjectTracker(dt=1./15.)

for i in range(43):
    ret, frame = cap.read()
    
time_stamp = stamps[0]
idx = 0
    
for j in tqdm(range(600)):
    ret, frame = cap.read()
    
    idx += np.argmin([abs(stamps[idx] -  time_stamp) , abs(stamps[idx + 1] -  time_stamp)])
    
    center = [None] * filtered_point_cloud_1[idx].shape[0]
    
    for i in range(filtered_point_cloud_1[idx].shape[0]):
        center[i] = (int(125 + 20.5*filtered_point_cloud_1[idx][i, 0]), int(735 - 20*filtered_point_cloud_1[idx][i, 1]))
        # 130 and 734 here are for translating the coordinate, 20 here is for scaling the resolution of the data to match the video resolution

    for i in range(len(center)):
        frame = cv2.circle(frame, center[i], radius=0, color=(0, 0, 255), thickness=-1) # circle function is for ploting the point cloud data on the picture frame
    detections = []
    for i in range(len(clustered_point_cloud[idx])):
        detections.append(Detection(box=np.array(clustered_point_cloud[idx][i][0]+clustered_point_cloud[idx][i][1])))
    tracker.step(detections=detections)
    tracks = tracker.active_tracks()
    for track in tracks:
        # print(track.id)
        # print(track.box)
        box = np.int64(track.box)
        cv2.putText(frame,track.id, (int(box[0]),box[1]-5), cv2.FONT_HERSHEY_SIMPLEX, 0.25, 255)
        frame = cv2.rectangle(frame, pt1 = box[:2], pt2 = box[2:], color=(255,0,0), thickness=2)

    #for i in range(len(clustered_point_cloud[idx])):
    #    frame = cv2.rectangle(frame, pt1 = clustered_point_cloud[idx][i][0], pt2 = clustered_point_cloud[idx][i][1], color=(255,0,0), thickness=1)
        
    out.write(frame)
    
    time_stamp += 1/15
        
out.release()

plt.imshow(frame)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:17<00:00, 34.35it/s]

# %% [markdown]
# **Rough Work and Testing below this part:**

# %%
# writing on the video

cap = cv2.VideoCapture('output1640b_transformed.mp4')
out = cv2.VideoWriter('synchronization_filtered_demo.mp4', cv2.VideoWriter_fourcc(*'mp4v'), 15, (832, 832))

counter = 0

for i in range(43):
    ret, frame = cap.read()
    
time_stamp = stamps[0]
idx = 0
    
for j in tqdm(range(600)):
    ret, frame = cap.read()
    
    idx += np.argmin([abs(stamps[idx] -  time_stamp) , abs(stamps[idx + 1] -  time_stamp)])
    
    center = [None] * filtered_point_cloud_1[idx].shape[0]
    
    for i in range(filtered_point_cloud_1[idx].shape[0]):
        center[i] = (int(125 + 20.5*filtered_point_cloud_1[idx][i, 0]), int(735 - 20*filtered_point_cloud_1[idx][i, 1]))        # 130 and 734 here are for translating the coordinate, 20 here is for scaling the resolution of the data to match the video resolution

    for i in range(len(center)):
        synchronization_image = cv2.circle(frame, center[i], radius=0, color=(0, 0, 255), thickness=-1) # circle function is for ploting the point cloud data on the picture frame

    out.write(synchronization_image)
    
    time_stamp += 1/15
            
out.release()
plt.imshow(synchronization_image)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:13<00:00, 45.89it/s]

# %%
import numpy as np
import matplotlib.pyplot as plt

x = cloud_arrays[1][:,0]
y = cloud_arrays[1][:,1]
z = cloud_arrays[1][:,2]

# Creating figure
fig = plt.figure(figsize = (10, 7))
ax = fig.add_subplot(projection='3d')

# Creating plot
ax.scatter( x, y, z, s = 0.001, color = "red")
ax.view_init(azim=0, elev=90)
plt.title("Original Point Cloud")
 
# show plot
plt.show()

x = filtered_point_cloud_1[1][:,0]
y = filtered_point_cloud_1[1][:,1]
z = filtered_point_cloud_1[1][:,2]

# Creating figure
fig = plt.figure(figsize = (10, 7))
ax = fig.add_subplot(projection = '3d')

# Creating plot
ax.scatter(x, y, z, s = 0.001, color = "red")
ax.view_init(azim=0, elev=90)
plt.title("Filtered Point Cloud")

    
# show plot
plt.show()

# %%
filtered_point_cloud_1 = []

for i in tqdm(range(len(filtered_point_cloud))):
    tmp = rotation_matrix(0, 0, -43).dot(filtered_point_cloud[i][:,0:3].T).T
    tmp = rotation_matrix(25, -5, 0).dot(tmp.T).T
    filtered_point_cloud_1.append(rotation_matrix(0, 0, 0).dot(tmp.T).T)
# Out:
# 100%|██████████| 600/600 [00:00<00:00, 3975.54it/s]

# %%
# Extracting frame

cap = cv2.VideoCapture('output1640b_transformed.mp4')
out = cv2.VideoWriter('synchronization_filtered_demo.mp4', cv2.VideoWriter_fourcc(*'mp4v'), 15, (832, 832))

counter = 0

for i in range(644):
    ret, frame = cap.read()  

center = [None] * filtered_point_cloud_1[idx].shape[0]

idx = 399
    
for i in range(filtered_point_cloud_1[idx].shape[0]):
    center[i] = (int(130 + 20.5*filtered_point_cloud_1[idx][i, 0]), int(735 - 20*filtered_point_cloud_1[idx][i, 1]))
    # 130 and 734 here are for translating the coordinate, 20 here is for scaling the resolution of the data to match the video resolution

for i in range(len(center)):
    synchronization_image = cv2.circle(frame, center[i], radius=0, color=(0, 0, 255), thickness=-1) # circle function is for ploting the point cloud data on the picture frame

plt.imshow(synchronization_image)

# %%
from sklearn.cluster import DBSCAN
import time
X = filtered_point_cloud[399][:,0:2]
print(X.shape)
start_time  = time.time()
db = DBSCAN(eps=0.6, min_samples=17).fit(X)
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print("Estimated number of clusters: %d" % n_clusters_)
print("Estimated number of noise points: %d" % n_noise_)
end_time = time.time()
print(end_time-start_time)
# Out:
# (7461, 2)
# Estimated number of clusters: 58
# Estimated number of noise points: 2953
# 0.05856776237487793

# %%
unique_labels = set(labels)
core_samples_mask = np.zeros_like(labels, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True

colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    
    col = [0, 0, 0, 1]
    
    if k == -1:
        # Black used for noise.
        col = [0,0,0,0]
        continue

    class_member_mask = labels == k

    xy = X[class_member_mask & core_samples_mask]
        
    if xy.shape[0]>0:
        plt.scatter(
            xy[:, 0],
            xy[:, 1],
            color = tuple(col),
    #         markeredgecolor="k",
            s = 0.1,
        )

    
        rect = patches.Rectangle((np.min(xy[:, 0]), np.min(xy[:, 1])), np.max(xy[:, 0])-np.min(xy[:, 0]), np.max(xy[:, 1])-np.min(xy[:, 1]), linewidth=1, edgecolor=tuple(col), facecolor='none')
        plt.gca().add_patch(rect)

plt.title(f"Estimated number of clusters: {n_clusters_}")
plt.show()
plt.show()

x = filtered_point_cloud[399][:,0]
y = filtered_point_cloud[399][:,1]
z = filtered_point_cloud[399][:,2]

# Creating figure
fig = plt.figure(figsize = (10, 7))
# ax = fig.add_subplot(projection = '3d')

# Creating plot
plt.scatter(x, y, s = 0.001, color = "red")
plt.title("Filtered Point Cloud")
 
# show plot
plt.show()

# %%
n, bins, patches = plt.hist(x=-1*cloud_arrays[0][:,0], bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.show()
print(idx)
# Out:
# 399

# %%
print(np.mean(cloud_arrays[0][:,0]), np.mean(cloud_arrays[0][:,1]), np.mean(cloud_arrays[0][:,2]))
# Out:
# 8.5318 -1.8553587 0.0097642215

# %%
# !conda install -c anaconda scikit-learn
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.3.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/rajatyagi/anaconda3/envs/myenv
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.4.26  |       hecd8cb5_0         132 KB  anaconda
#     certifi-2022.6.15          |  py310hecd8cb5_0         157 KB  anaconda
#     joblib-1.1.0               |     pyhd3eb1b0_0         211 KB  anaconda
#     scikit-learn-1.0.2         |  py310hc081a56_0         7.4 MB  anaconda
#     threadpoolctl-2.2.0        |     pyh0d69192_0          16 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         7.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   joblib             anaconda/noarch::joblib-1.1.0-pyhd3eb1b0_0
#   scikit-learn       anaconda/osx-64::scikit-learn-1.0.2-py310hc081a56_0
#   threadpoolctl      anaconda/noarch::threadpoolctl-2.2.0-pyh0d69192_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2022.12.~ --> anaconda::ca-certificates-2022.4.26-hecd8cb5_0
#   certifi            conda-forge/noarch::certifi-2022.12.7~ --> anaconda/osx-64::certifi-2022.6.15-py310hecd8cb5_0
#   openssl            conda-forge::openssl-1.1.1t-hfd90126_0 --> pkgs/main::openssl-1.1.1t-hca72f7f_0
#
#
# Proceed ([y]/n)? ^C
#
# CondaSystemExit:
# Operation aborted.  Exiting.

# %%
# %load_ext cython
